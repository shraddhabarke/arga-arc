# %%
import lark
from lark import Lark, Transformer, v_args, Visitor
from collections import Counter
import json
import numpy as np

# %%
sexpr_grammar_path = "dsl/sexpr.lark"
sexpr_grammar = open(sexpr_grammar_path).read()
sexpr_parser = Lark(sexpr_grammar, start='sexpr')

# This visitor computes a map with the number of times each atom appears in the S-Expression
class SExprStats(Visitor):
    def __init__(self) -> None:
        super().__init__()
        self.counts = Counter()

    def atom(self, atom):
        name = atom.children[0].value
        self.counts[name] += 1

# %%
sexpr_example = """
(
    (a 1)
    (
        (b 2)
        (a 3)
    )
)
"""
sexpr_tree = sexpr_parser.parse(sexpr_example)
print(sexpr_tree.pretty())

stats = SExprStats()
stats.visit(sexpr_tree)
print(stats.counts)
# Out:
# sexpr
#   sexpr
#     sexpr
#       atom	a
#     sexpr
#       atom	1
#   sexpr
#     sexpr
#       sexpr
#         atom	b
#       sexpr
#         atom	2
#     sexpr
#       sexpr
#         atom	a
#       sexpr
#         atom	3
#
# Counter({'a': 2, 'b': 1, '2': 1, '3': 1, '1': 1})

# %%
def parse_entry(entry):
    task_id, valid, invalid = entry
    task_id = task_id.split(" ")[1]
    valid = int(valid.split(": ")[1])
    invalid = int(invalid.split(": ")[1])

    return task_id, valid, invalid

def parse_log(log_path):
    with open(log_path, "r") as f:
        log = f.read()

    log = log.splitlines()
    header = log[:3]
    log = log[3:]

    model = header[1].split(": ")[1]
    num_gens = int(header[2].split(": ")[1])

    assert len(log) % 3 == 0

    log = list(zip(*[iter(log)]*3))
    log = [parse_entry(entry) for entry in log]

    return model, num_gens, log

def try_parse_sexpr(code):
    try:
        code_tree = sexpr_parser.parse(code)
        return code , "valid", code_tree
    except Exception as e:
        # print(e)
        pass
    rep_code = "(" + code
    try:
        code_tree = sexpr_parser.parse(rep_code)
        return rep_code, "paren_l", code_tree
    except Exception as e:
        # print(e)
        pass
    rep_code = code + ")"
    try:
        code_tree = sexpr_parser.parse(rep_code)
        return rep_code, "paren_r", code_tree
    except Exception as e:
        # print(e)
        pass
    return code, "invalid", None

# gens_path = "dsl/v0_3/generations/gens_test"
# gens_path = "dsl/v0_3/generations/arga_gpt4o_m100_20240516"
gens_path = "models/logs/gens_20240521T224005_gpt3"

# read the log file
with open(gens_path + "/log.txt") as f:
    log = f.read()

# parse the log file
model, num_gens, log = parse_log(gens_path + "/log.txt")
print(model, num_gens)

all_tasks_count = {}

# log = log[:1]
print(len(log))
for task_id, n_valid, n_invalid in log:
    valid_file = gens_path + f"/{task_id}_valid.txt"
    invalid_file = gens_path + f"/{task_id}_invalid.txt"

    with open(valid_file, "r") as f:
        valid = json.load(f)
    with open(invalid_file, "r") as f:
        invalid = json.load(f)

    all = []
    for entry in valid:
        response = json.loads(entry)
        all.append(response["code"])
    for entry in invalid:
        try:
            response = json.loads(entry["response"])
        except:
            print(f"Incorrect entry: {entry}")
        # response = json.loads(entry["response"])
        all.append(response["code"])
    # print(f"Task {task_id}: {n_valid} valid, {n_invalid} invalid")
    print(f"Task {task_id}:")
    assert n_valid + n_invalid == len(all)
    print(f"{len(valid)}/{len(all)} valid")
    # lib = f"(\n{''.join(all)}\n)"
    #parse the library
    # lib_tree = sexpr_parser.parse(lib)
    global_counter = Counter()
    task_stats = {
        # "task_id": task_id,
        "per_solution_counts": []
    }
    emp_valid = 0
    repaired = 0
    skipped = 0
    for code in all:
        # print(code)
        code, parse_status, code_tree = try_parse_sexpr(code)
        if parse_status == "invalid":
            skipped += 1
            continue
        elif parse_status != "valid":
            repaired += 1
        elif parse_status == "valid":
            emp_valid += 1

        # print(code_tree.pretty())
        stats = SExprStats()
        stats.visit(code_tree)
        counts = stats.counts
        global_counter += counts
        entry = {
            "code": code,
            "parse_status": parse_status,
            "counts": counts
        }
        task_stats["per_solution_counts"].append(entry)
    task_stats["total_counts"] = global_counter
    # print(json.dumps(global_stats, indent=4))
    print(f"{emp_valid}/{len(all)} check valid")
    print(f"{repaired}/{len(all)} repaired")
    print(f"{skipped}/{len(all)} skipped")

    all_tasks_count[task_id] = task_stats

# save it to gens directory
counts_path = gens_path + f"/counts.json"
# counts_path = gens_path + f"/counts_temp.json"
with open(counts_path, "w") as f:
    json.dump(all_tasks_count, f, indent=4)
    print(f"Counts saved to {counts_path}")
# Out:
# gpt-3.5-turbo-0125 128
# 80
# Task 00d62c1b:
# 114/128 valid
# 127/128 check valid
# 0/128 repaired
# 1/128 skipped
# Task 025d127b:
# 111/128 valid
# 127/128 check valid
# 0/128 repaired
# 1/128 skipped
# Task 05f2a901:
# 110/128 valid
# 127/128 check valid
# 1/128 repaired
# 0/128 skipped
# Task 08ed6ac7:
# 93/128 valid
# 125/128 check valid
# 2/128 repaired
# 1/128 skipped
# Task 0962bcdd:
# 100/128 valid
# 127/128 check valid
# 0/128 repaired
# 1/128 skipped
# Task 0ca9ddb6:
# 110/128 valid
# 128/128 check valid
# 0/128 repaired
# 0/128 skipped
# Task 0d3d703e:
# 92/128 valid
# 126/128 check valid
# 0/128 repaired
# 2/128 skipped
# Task 0e206a2e:
# 112/128 valid
# 127/128 check valid
# 1/128 repaired
# 0/128 skipped
# Task 150deff5:
# 96/128 valid
# 127/128 check valid
# 1/128 repaired
# 0/128 skipped
# Task 1a07d186:
# 102/128 valid
# 127/128 check valid
# 0/128 repaired
# 1/128 skipped
# Task 1b60fb0c:
# 102/128 valid
# 128/128 check valid
# 0/128 repaired
# 0/128 skipped
# Task 1caeab9d:
# 114/128 valid
# 128/128 check valid
# 0/128 repaired
# 0/128 skipped
# Task 1e0a9b12:
# 106/128 valid
# 125/128 check valid
# 0/128 repaired
# 3/128 skipped
# Task 1f0c79e5:
# 110/128 valid
# 127/128 check valid
# 0/128 repaired
# 1/128 skipped
# Task 2204b7a8:
# 97/128 valid
# 126/128 check valid
# 0/128 repaired
# 2/128 skipped
# Task 22168020:
# 116/128 valid
# 127/128 check valid
# 0/128 repaired
# 1/128 skipped
# Task 22233c11:
# 109/128 valid
# 127/128 check valid
# 0/128 repaired
# 1/128 skipped
# Task 228f6490:
# 104/128 valid
# 127/128 check valid
# 0/128 repaired
# 1/128 skipped
# Task 22eb0ac0:
# 105/128 valid
# 128/128 check valid
# 0/128 repaired
# 0/128 skipped
# Task 25d487eb:
# 111/128 valid
# 128/128 check valid
# 0/128 repaired
# 0/128 skipped
# Task 25d8a9c8:
# 119/128 valid
# 128/128 check valid
# 0/128 repaired
# 0/128 skipped
# Task 25ff71a9:
# 114/128 valid
# 127/128 check valid
# 0/128 repaired
# 1/128 skipped
# Task 272f95fa:
# 112/128 valid
# 127/128 check valid
# 0/128 repaired
# 1/128 skipped
# Task 29c11459:
# 110/128 valid
# 128/128 check valid
# 0/128 repaired
# 0/128 skipped
# Task 2c608aff:
# 114/128 valid
# 128/128 check valid
# 0/128 repaired
# 0/128 skipped
# Task 31aa019c:
# 104/128 valid
# 128/128 check valid
# 0/128 repaired
# 0/128 skipped
# Task 321b1fc6:
# 104/128 valid
# 128/128 check valid
# 0/128 repaired
# 0/128 skipped
# Task 32597951:
# 106/128 valid
# 127/128 check valid
# 1/128 repaired
# 0/128 skipped
# Task 3618c87e:
# 99/128 valid
# 128/128 check valid
# 0/128 repaired
# 0/128 skipped
# Task 363442ee:
# 102/128 valid
# 128/128 check valid
# 0/128 repaired
# 0/128 skipped
# Task 36d67576:
# 103/128 valid
# 128/128 check valid
# 0/128 repaired
# 0/128 skipped
# Task 36fdfd69:
# 100/128 valid
# 126/128 check valid
# 1/128 repaired
# 1/128 skipped
# Task 3906de3d:
# 101/128 valid
# 128/128 check valid
# 0/128 repaired
# 0/128 skipped
# Task 39e1d7f9:
# 114/128 valid
# 125/128 check valid
# 1/128 repaired
# 2/128 skipped
# Task 3aa6fb7a:
# 85/128 valid
# 127/128 check valid
# 0/128 repaired
# 1/128 skipped
# Task 3bdb4ada:
# 99/128 valid
# 126/128 check valid
# 1/128 repaired
# 1/128 skipped
# Task 3c9b0459:
# 102/128 valid
# 128/128 check valid
# 0/128 repaired
# 0/128 skipped
# Task 3e980e27:
# 104/128 valid
# 128/128 check valid
# 0/128 repaired
# 0/128 skipped
# Task 3eda0437:
# 113/128 valid
# 128/128 check valid
# 0/128 repaired
# 0/128 skipped
# Incorrect entry: {'response': '{\n    "nl_description": "Recolor all objects to color X, except the object at coordinates (7, 7), which is colored O.",\n    "code": "(do\\n    (rule\\n        (vars (this))\\n        (filter)\\n        (apply\\n            (update_color X)\\n        )\\n    )\\n    (rule\\n        (vars (this))\\n        (filter\\n            (and\\n                (=",\n  "color_equals (color_of this) O) n                (=" \t\t\t\t\n  \t\t\t\t\t \t\t\t\t\t   \t  \t\t\t\t           \t\n  \t\t\t\t\t\t \t\t\t\t\t\t\t\t\t\t\t\t  \t\t\t\t\t \t\t\t\t\t\t\t\t \t\t\t \t \n\t\t\t\t\t\t\t \t \t\t                                        \t\t\t\t  \t \t\n\t\t\t\t \t\t\t\t\t\t      \t\t\t\t    \t\t\t\t\t\r\n    \t\t\t\t\t      \t   \t \t\t \t \t\t\t      \t          \t\t   \t  \t \t         \t         \t\t\t  \t \t  \t \t  \n  \t \t \t\t\t                                                       \t \n  \t \t \t \t \t  \t \t  \t \t  \t     \t\t   \t\n  \t \t \t \t \t  \t\t\t      \t \t\t\t \t\t\t \t   \t  \t\t \t \n  \t \t \t \t \t \t\t\t\t\t \t\t\t\t\t    \t   \t\t\t\t\t\t\t\n    \t \t \t\t\t                                          \t\t\t\t   \t  \t     \t\n  \t\t\t\t\t\t \t   \t \t \t\t\t\t \t\t\t  \t\n    \t                                        \t\t\t\t \t  \t\n   \t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t \n  \t\t\t\t        \n       \t\t\t\t\t \t  \n  \t  \t\t\t\t\t \t\t\t\t\t                \t\t   \t  \t \t   \t   \n   \t\t\t\t\t\t\t    \t\t\t\t  \n   \t \t \t\t \t \t\t    \t \t\t         \t  \t \t\n  \t\t\t\t\t\t  \t\t\t\t\t \t \t\t\t\t \t    \t \t\t\t\t\t\r\n  \t\t\t\t\t\t\t\t\t\t                    \t      \t  \t \t\t \t \t\t\t \t           \t \n                                                                                   \t\n    \t\t\t\t\t\t     \t \t\t            \t\r\n    \t \t \t\t\t \t \t\t\t \t\n    \t\t\t\t\t\t   \t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t \n    \t    \t\t\t\t\t\t\t \t\t\t\t\t\t\r\n          \t\t\t\t           \t\t\t\t \t  \t\t\t \n\t\t\t\t \t\t\t\t\t\t\t  \t\t\t\t\t\t\t\t\t\t \t \r\n    \t\t\t \t\t\t\t\t\t\t  \t   \t\t \t     \r\n  \t\t\t\t\t       \t\t\t\t\t\t       \t\t\t\t\t\t\t\n\t\t\t\t \t\t\t\t\t\t\t\t\t\t\t\t  \n              \t\t\t\t\t\t\t  \t  \n    \t\t\t\t\t\t\t\t\t\t \t  \n    \t\t\t\t\t \n               \t\t\t        \t\t\t  \t \n    \t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t  \n    \t\t\t\t\t\t\t    \t\t\t\t\t                \t\t\t\t   \r\n  \t\t\t\t \t\t\t\t \t                                                              \n    \t \t\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t   \r\n       \t\t\t\t\t\t    \t \t   \t  \t \t\t             \n   \t\t \t         \t                                                                                       \t\t\t\t                 \n  \t\t\t\t\t\t\t\t\t\t\t\t  \n    \t\t\t   \t   \t\t \t                        \t\t \n    \t  \t\t\t\t  \t  \t \t\t\t\t \t    \t \t\t\t  \t \t\t \n         \t\t\t\t \t          \t      \t\t\t\t\t\t\t\t\t\t\t\t\t\t\t \n    \t \t\t\t   \t\t\t\t\t\t\t\t\t            \t       \t \t\t     \t\r\n   \t\t\t\t\t \t     \n    \t\t\t\t\t\t\t\t\t\t\t\t \t\t\n\t       \t   \t\t\t   \t          \n  \t \t \t\t\t\t\t\t\t\t\t\t\t\t\n    \t\t\t\t\t   \t \t  \t  \t \t   \t \t   \t \n        \t\t\t\t \t       \t\n  \t  \t\t\t\t\t\t\t\t\t\t\t\t\t\t\t          \n      \t\t\t\t\t\t\t\t\n  \t\t \t   \t  \t          \t \t\t\t \t\t\t \n            \t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t  \n       \t\t\t\t\t\t\t\t\t\t\t\t\t\t\t     \t\t\t    \t  \r\n   \t\t\t\t\t\t\t\t\t\t\t  \t   \t\t\t\t\t\t\t\t\t\t     \n  \t\t\t\t\t               \n    \t\t\t\t \t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n  \t   \t\t\t\t\t\t\t\t\t\t\t\t   \t \n  \t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t \t \t \t \t\t\r\n   \t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n \t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t \t\t\t\t\t\t\t\t\t\t \t \r\n                           \t\t  \t \t  \t  \t\n       \t\t\t     ...
# Task 4093f84a:
# 109/128 valid
# 126/128 check valid
# 1/128 repaired
# 1/128 skipped
# Task 41e4d17e:
# 106/128 valid
# 127/128 check valid
# 0/128 repaired
# 1/128 skipped
# Task 4258a5f9:
# 104/128 valid
# 127/128 check valid
# 1/128 repaired
# 0/128 skipped
# Task 42a50994:
# 115/128 valid
# 128/128 check valid
# 0/128 repaired
# 0/128 skipped
# Task 4347f46a:
# 100/128 valid
# 127/128 check valid
# 1/128 repaired
# 0/128 skipped
# Task 444801d8:
# 108/128 valid
# 127/128 check valid
# 1/128 repaired
# 0/128 skipped
# Task 447fd412:
# 108/128 valid
# 126/128 check valid
# 1/128 repaired
# 1/128 skipped
# Task 44d8ac46:
# 116/128 valid
# 127/128 check valid
# 0/128 repaired
# 1/128 skipped
# Task 4612dd53:
# 108/128 valid
# 127/128 check valid
# 1/128 repaired
# 0/128 skipped
# Task 50846271:
# 109/128 valid
# 128/128 check valid
# 0/128 repaired
# 0/128 skipped
# Task 50cb2852:
# 102/128 valid
# 127/128 check valid
# 1/128 repaired
# 0/128 skipped
# Task 5168d44c:
# 116/128 valid
# 128/128 check valid
# 0/128 repaired
# 0/128 skipped
# Task 543a7ed5:
# 102/128 valid
# 125/128 check valid
# 2/128 repaired
# 1/128 skipped
# Task 54d9e175:
# 112/128 valid
# 128/128 check valid
# 0/128 repaired
# 0/128 skipped
# Task 5521c0d9:
# 113/128 valid
# 126/128 check valid
# 1/128 repaired
# 1/128 skipped
# Task 5582e5ca:
# 128/128 valid
# 128/128 check valid
# 0/128 repaired
# 0/128 skipped
# Task 57aa92db:
# 109/128 valid
# 127/128 check valid
# 1/128 repaired
# 0/128 skipped
# Task 5c0a986e:
# 105/128 valid
# 127/128 check valid
# 1/128 repaired
# 0/128 skipped
# Incorrect entry: {'response': '{\n    "nl_description": "For each group of connected components (objects of the same color connected horizontally or vertically), color the top-left component of each group with color A.",\n    "code": "(do\\n    (rule\\n        (vars (this))"\n        ,"\\n        (apply\\n            (update_color A)\\n        )"\n        \n        \n        \n        \n        \n        \n       \n        \n        \n        \n        \n        \n        \n    \n        \n        \n        \n        \n        \n        \n        \n        \n    \n        \n        \n        \n        \n        \n        \n        \n        \n    \n        \n        \n        \n        \n        \n        \n        \n        \n     \n    \n        \n        \n        \n        \n        \n        \n        \n        \n        \n    \n        \n        \n        \n        \n        \n        \n        \n        \n    \n        \n        \n        \n        \n        \n        \n        \n        \n    \n        \n        \n        \n        \n        \n        \n        \n        \n    \n        \n        \n        \n        \n        \n        \n        \n        \n        \n    \n        \n        \n        \n        \n        \n        \n        \n        \n    \n        \n        \n        \n        \n        \n        \n        \n        \n    \n        \n        \n        \n        \n        \n        \n        \n        \n        \n    \n        \n        \n        \n        \n        \n        \n        \n        \n    \n        \n        \n        ', 'error_type': 'json_parse_error', 'error_message': "Expecting ':' delimiter: line 133 column 9 (char 1414)"}
# Task 60b61512:
# 97/128 valid
# 126/128 check valid
# 0/128 repaired
# 2/128 skipped
# Task 6150a2bd:
# 113/128 valid
# 126/128 check valid
# 1/128 repaired
# 1/128 skipped
# Task 63613498:
# 111/128 valid
# 128/128 check valid
# 0/128 repaired
# 0/128 skipped
# Task 6455b5f5:
# 106/128 valid
# 127/128 check valid
# 0/128 repaired
# 1/128 skipped
# Task 67385a82:
# 112/128 valid
# 128/128 check valid
# 0/128 repaired
# 0/128 skipped
# Task 67a3c6ac:
# 114/128 valid
# 128/128 check valid
# 0/128 repaired
# 0/128 skipped
# Task 67a423a3:
# 103/128 valid
# 128/128 check valid
# 0/128 repaired
# 0/128 skipped
# Task 6855a6e4:
# 109/128 valid
# 128/128 check valid
# 0/128 repaired
# 0/128 skipped
# Task 68b16354:
# 108/128 valid
# 126/128 check valid
# 1/128 repaired
# 1/128 skipped
# Task 694f12f3:
# 81/128 valid
# 126/128 check valid
# 0/128 repaired
# 2/128 skipped
# Task 6a1e5592:
# 110/128 valid
# 128/128 check valid
# 0/128 repaired
# 0/128 skipped
# Task 6aa20dc0:
# 113/128 valid
# 127/128 check valid
# 1/128 repaired
# 0/128 skipped
# Task 6c434453:
# 106/128 valid
# 127/128 check valid
# 0/128 repaired
# 1/128 skipped
# Task 6d58a25d:
# 111/128 valid
# 126/128 check valid
# 1/128 repaired
# 1/128 skipped
# Task 6d75e8bb:
# 103/128 valid
# 126/128 check valid
# 0/128 repaired
# 2/128 skipped
# Task 6e82a1ae:
# 112/128 valid
# 128/128 check valid
# 0/128 repaired
# 0/128 skipped
# Task 72322fa7:
# 103/128 valid
# 127/128 check valid
# 0/128 repaired
# 1/128 skipped
# Task 7447852a:
# 107/128 valid
# 126/128 check valid
# 1/128 repaired
# 1/128 skipped
# Task 74dd1130:
# 110/128 valid
# 127/128 check valid
# 1/128 repaired
# 0/128 skipped
# Task 776ffc46:
# 106/128 valid
# 127/128 check valid
# 0/128 repaired
# 1/128 skipped
# Task 794b24be:
# 123/128 valid
# 127/128 check valid
# 1/128 repaired
# 0/128 skipped
# Task 7b6016b9:
# 113/128 valid
# 128/128 check valid
# 0/128 repaired
# 0/128 skipped
# Task 7ddcd7ec:
# 104/128 valid
# 127/128 check valid
# 0/128 repaired
# 1/128 skipped
# Counts saved to models/logs/gens_20240521T224005_gpt3/counts.json

# %% [markdown]
# # Get counts only for invalid

# %%
# gens_path = "dsl/v0_3/generations/gens_test"
# gens_path = "dsl/v0_3/generations/arga_gpt4o_m100_20240516"
gens_path = "models/logs/gens_20240521T224005_gpt3"

# read the log file
with open(gens_path + "/log.txt") as f:
    log = f.read()

# parse the log file
model, num_gens, log = parse_log(gens_path + "/log.txt")
print(model, num_gens)

invalid_stats = {
    "per_task": {},
}

# log = log[:1]
print(f"{len(log)} tasks") 
all_total, all_valid, all_invalid, all_repaired = 0, 0, 0, 0
for task_id, n_valid, n_invalid in log:
    n_total = n_valid + n_invalid

    valid_file = gens_path + f"/{task_id}_valid.txt"
    invalid_file = gens_path + f"/{task_id}_invalid.txt"

    with open(valid_file, "r") as f:
        valid = json.load(f)
    with open(invalid_file, "r") as f:
        invalid = json.load(f)
    assert len(valid) == n_valid
    assert len(invalid) == n_invalid

    all_total += n_total
    all_valid += n_valid
    all_invalid += n_invalid

    invalid_ratio = n_invalid / n_total 


    # shuffle invlaid entries
    np.random.shuffle(invalid)

    cummulative_counts = []
    current_counts = Counter()
    for entry in invalid:
        try:
            response = json.loads(entry["response"])
        except:
            print(f"Incorrect entry: {entry}")
        code = response["code"]
        code, parse_status, code_tree = try_parse_sexpr(code)
        if parse_status == "invalid":
            continue
        stats = SExprStats()
        stats.visit(code_tree)
        current_counts += counts
        cummulative_counts.append(current_counts.copy())
        # cummulative_counts.append(current_counts)

    n_repaired = len(cummulative_counts)
    all_repaired += n_repaired

    invalid_stats["per_task"][task_id] = {
        "n_total": n_total,
        "n_invalid": n_invalid,
        "invalid_ratio": invalid_ratio,
        "n_repaired": n_repaired,
        "cummulative_counts": cummulative_counts,
    }

    print(f"Task {task_id}:")
    print(f"  {n_invalid}/{n_total} invalid")
    print(f"  {invalid_ratio:.2f} invalid ratio")
    print(f"  {n_repaired}/{n_invalid} repaired")

invalid_stats["all"] = {
    "n_total": all_total,
    "n_invalid": all_invalid,
    "invalid_ratio": all_invalid / all_total,
    "n_repaired": all_repaired,
}
print(json.dumps(invalid_stats, indent=4))

# # save it to gens directory
# invalid_stats_path = gens_path + f"/invalid_counts.json"
# with open(invalid_stats_path, "w") as f:
#     json.dump(invalid_stats, f, indent=4)
#     print(f"Counts saved to {invalid_stats_path}")
# Out:
# gpt-3.5-turbo-0125 128
# 80 tasks
# Task 00d62c1b:
#   14/128 invalid
#   0.11 invalid ratio
#   13/14 repaired
# Task 025d127b:
#   17/128 invalid
#   0.13 invalid ratio
#   16/17 repaired
# Task 05f2a901:
#   18/128 invalid
#   0.14 invalid ratio
#   18/18 repaired
# Task 08ed6ac7:
#   35/128 invalid
#   0.27 invalid ratio
#   34/35 repaired
# Task 0962bcdd:
#   28/128 invalid
#   0.22 invalid ratio
#   27/28 repaired
# Task 0ca9ddb6:
#   18/128 invalid
#   0.14 invalid ratio
#   18/18 repaired
# Task 0d3d703e:
#   36/128 invalid
#   0.28 invalid ratio
#   34/36 repaired
# Task 0e206a2e:
#   16/128 invalid
#   0.12 invalid ratio
#   16/16 repaired
# Task 150deff5:
#   32/128 invalid
#   0.25 invalid ratio
#   32/32 repaired
# Task 1a07d186:
#   26/128 invalid
#   0.20 invalid ratio
#   25/26 repaired
# Task 1b60fb0c:
#   26/128 invalid
#   0.20 invalid ratio
#   26/26 repaired
# Task 1caeab9d:
#   14/128 invalid
#   0.11 invalid ratio
#   14/14 repaired
# Task 1e0a9b12:
#   22/128 invalid
#   0.17 invalid ratio
#   19/22 repaired
# Task 1f0c79e5:
#   18/128 invalid
#   0.14 invalid ratio
#   17/18 repaired
# Task 2204b7a8:
#   31/128 invalid
#   0.24 invalid ratio
#   29/31 repaired
# Task 22168020:
#   12/128 invalid
#   0.09 invalid ratio
#   11/12 repaired
# Task 22233c11:
#   19/128 invalid
#   0.15 invalid ratio
#   18/19 repaired
# Task 228f6490:
#   24/128 invalid
#   0.19 invalid ratio
#   23/24 repaired
# Task 22eb0ac0:
#   23/128 invalid
#   0.18 invalid ratio
#   23/23 repaired
# Task 25d487eb:
#   17/128 invalid
#   0.13 invalid ratio
#   17/17 repaired
# Task 25d8a9c8:
#   9/128 invalid
#   0.07 invalid ratio
#   9/9 repaired
# Task 25ff71a9:
#   14/128 invalid
#   0.11 invalid ratio
#   13/14 repaired
# Task 272f95fa:
#   16/128 invalid
#   0.12 invalid ratio
#   15/16 repaired
# Task 29c11459:
#   18/128 invalid
#   0.14 invalid ratio
#   18/18 repaired
# Task 2c608aff:
#   14/128 invalid
#   0.11 invalid ratio
#   14/14 repaired
# Task 31aa019c:
#   24/128 invalid
#   0.19 invalid ratio
#   24/24 repaired
# Task 321b1fc6:
#   24/128 invalid
#   0.19 invalid ratio
#   24/24 repaired
# Task 32597951:
#   22/128 invalid
#   0.17 invalid ratio
#   22/22 repaired
# Task 3618c87e:
#   29/128 invalid
#   0.23 invalid ratio
#   29/29 repaired
# Task 363442ee:
#   26/128 invalid
#   0.20 invalid ratio
#   26/26 repaired
# Task 36d67576:
#   25/128 invalid
#   0.20 invalid ratio
#   25/25 repaired
# Task 36fdfd69:
#   28/128 invalid
#   0.22 invalid ratio
#   27/28 repaired
# Task 3906de3d:
#   27/128 invalid
#   0.21 invalid ratio
#   27/27 repaired
# Task 39e1d7f9:
#   14/128 invalid
#   0.11 invalid ratio
#   12/14 repaired
# Task 3aa6fb7a:
#   43/128 invalid
#   0.34 invalid ratio
#   42/43 repaired
# Task 3bdb4ada:
#   29/128 invalid
#   0.23 invalid ratio
#   28/29 repaired
# Task 3c9b0459:
#   26/128 invalid
#   0.20 invalid ratio
#   26/26 repaired
# Task 3e980e27:
#   24/128 invalid
#   0.19 invalid ratio
#   24/24 repaired
# Task 3eda0437:
#   15/128 invalid
#   0.12 invalid ratio
#   15/15 repaired
# Incorrect entry: {'response': '{\n    "nl_description": "Recolor all objects to color X, except the object at coordinates (7, 7), which is colored O.",\n    "code": "(do\\n    (rule\\n        (vars (this))\\n        (filter)\\n        (apply\\n            (update_color X)\\n        )\\n    )\\n    (rule\\n        (vars (this))\\n        (filter\\n            (and\\n                (=",\n  "color_equals (color_of this) O) n                (=" \t\t\t\t\n  \t\t\t\t\t \t\t\t\t\t   \t  \t\t\t\t           \t\n  \t\t\t\t\t\t \t\t\t\t\t\t\t\t\t\t\t\t  \t\t\t\t\t \t\t\t\t\t\t\t\t \t\t\t \t \n\t\t\t\t\t\t\t \t \t\t                                        \t\t\t\t  \t \t\n\t\t\t\t \t\t\t\t\t\t      \t\t\t\t    \t\t\t\t\t\r\n    \t\t\t\t\t      \t   \t \t\t \t \t\t\t      \t          \t\t   \t  \t \t         \t         \t\t\t  \t \t  \t \t  \n  \t \t \t\t\t                                                       \t \n  \t \t \t \t \t  \t \t  \t \t  \t     \t\t   \t\n  \t \t \t \t \t  \t\t\t      \t \t\t\t \t\t\t \t   \t  \t\t \t \n  \t \t \t \t \t \t\t\t\t\t \t\t\t\t\t    \t   \t\t\t\t\t\t\t\n    \t \t \t\t\t                                          \t\t\t\t   \t  \t     \t\n  \t\t\t\t\t\t \t   \t \t \t\t\t\t \t\t\t  \t\n    \t                                        \t\t\t\t \t  \t\n   \t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t \n  \t\t\t\t        \n       \t\t\t\t\t \t  \n  \t  \t\t\t\t\t \t\t\t\t\t                \t\t   \t  \t \t   \t   \n   \t\t\t\t\t\t\t    \t\t\t\t  \n   \t \t \t\t \t \t\t    \t \t\t         \t  \t \t\n  \t\t\t\t\t\t  \t\t\t\t\t \t \t\t\t\t \t    \t \t\t\t\t\t\r\n  \t\t\t\t\t\t\t\t\t\t                    \t      \t  \t \t\t \t \t\t\t \t           \t \n                                                                                   \t\n    \t\t\t\t\t\t     \t \t\t            \t\r\n    \t \t \t\t\t \t \t\t\t \t\n    \t\t\t\t\t\t   \t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t \n    \t    \t\t\t\t\t\t\t \t\t\t\t\t\t\r\n          \t\t\t\t           \t\t\t\t \t  \t\t\t \n\t\t\t\t \t\t\t\t\t\t\t  \t\t\t\t\t\t\t\t\t\t \t \r\n    \t\t\t \t\t\t\t\t\t\t  \t   \t\t \t     \r\n  \t\t\t\t\t       \t\t\t\t\t\t       \t\t\t\t\t\t\t\n\t\t\t\t \t\t\t\t\t\t\t\t\t\t\t\t  \n              \t\t\t\t\t\t\t  \t  \n    \t\t\t\t\t\t\t\t\t\t \t  \n    \t\t\t\t\t \n               \t\t\t        \t\t\t  \t \n    \t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t  \n    \t\t\t\t\t\t\t    \t\t\t\t\t                \t\t\t\t   \r\n  \t\t\t\t \t\t\t\t \t                                                              \n    \t \t\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t   \r\n       \t\t\t\t\t\t    \t \t   \t  \t \t\t             \n   \t\t \t         \t                                                                                       \t\t\t\t                 \n  \t\t\t\t\t\t\t\t\t\t\t\t  \n    \t\t\t   \t   \t\t \t                        \t\t \n    \t  \t\t\t\t  \t  \t \t\t\t\t \t    \t \t\t\t  \t \t\t \n         \t\t\t\t \t          \t      \t\t\t\t\t\t\t\t\t\t\t\t\t\t\t \n    \t \t\t\t   \t\t\t\t\t\t\t\t\t            \t       \t \t\t     \t\r\n   \t\t\t\t\t \t     \n    \t\t\t\t\t\t\t\t\t\t\t\t \t\t\n\t       \t   \t\t\t   \t          \n  \t \t \t\t\t\t\t\t\t\t\t\t\t\t\n    \t\t\t\t\t   \t \t  \t  \t \t   \t \t   \t \n        \t\t\t\t \t       \t\n  \t  \t\t\t\t\t\t\t\t\t\t\t\t\t\t\t          \n      \t\t\t\t\t\t\t\t\n  \t\t \t   \t  \t          \t \t\t\t \t\t\t \n            \t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t  \n       \t\t\t\t\t\t\t\t\t\t\t\t\t\t\t     \t\t\t    \t  \r\n   \t\t\t\t\t\t\t\t\t\t\t  \t   \t\t\t\t\t\t\t\t\t\t     \n  \t\t\t\t\t               \n    \t\t\t\t \t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n  \t   \t\t\t\t\t\t\t\t\t\t\t\t   \t \n  \t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t \t \t \t \t\t\r\n   \t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n \t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t \t\t\t\t\t\t\t\t\t\t \t \r\n                           \t\t  \t \t  \t  \t\n       \t\t\t     ...
# Task 4093f84a:
#   19/128 invalid
#   0.15 invalid ratio
#   18/19 repaired
# Task 41e4d17e:
#   22/128 invalid
#   0.17 invalid ratio
#   21/22 repaired
# Task 4258a5f9:
#   24/128 invalid
#   0.19 invalid ratio
#   24/24 repaired
# Task 42a50994:
#   13/128 invalid
#   0.10 invalid ratio
#   13/13 repaired
# Task 4347f46a:
#   28/128 invalid
#   0.22 invalid ratio
#   28/28 repaired
# Task 444801d8:
#   20/128 invalid
#   0.16 invalid ratio
#   20/20 repaired
# Task 447fd412:
#   20/128 invalid
#   0.16 invalid ratio
#   19/20 repaired
# Task 44d8ac46:
#   12/128 invalid
#   0.09 invalid ratio
#   11/12 repaired
# Task 4612dd53:
#   20/128 invalid
#   0.16 invalid ratio
#   20/20 repaired
# Task 50846271:
#   19/128 invalid
#   0.15 invalid ratio
#   19/19 repaired
# Task 50cb2852:
#   26/128 invalid
#   0.20 invalid ratio
#   26/26 repaired
# Task 5168d44c:
#   12/128 invalid
#   0.09 invalid ratio
#   12/12 repaired
# Task 543a7ed5:
#   26/128 invalid
#   0.20 invalid ratio
#   25/26 repaired
# Task 54d9e175:
#   16/128 invalid
#   0.12 invalid ratio
#   16/16 repaired
# Task 5521c0d9:
#   15/128 invalid
#   0.12 invalid ratio
#   14/15 repaired
# Task 5582e5ca:
#   0/128 invalid
#   0.00 invalid ratio
#   0/0 repaired
# Task 57aa92db:
#   19/128 invalid
#   0.15 invalid ratio
#   19/19 repaired
# Task 5c0a986e:
#   23/128 invalid
#   0.18 invalid ratio
#   23/23 repaired
# Incorrect entry: {'response': '{\n    "nl_description": "For each group of connected components (objects of the same color connected horizontally or vertically), color the top-left component of each group with color A.",\n    "code": "(do\\n    (rule\\n        (vars (this))"\n        ,"\\n        (apply\\n            (update_color A)\\n        )"\n        \n        \n        \n        \n        \n        \n       \n        \n        \n        \n        \n        \n        \n    \n        \n        \n        \n        \n        \n        \n        \n        \n    \n        \n        \n        \n        \n        \n        \n        \n        \n    \n        \n        \n        \n        \n        \n        \n        \n        \n     \n    \n        \n        \n        \n        \n        \n        \n        \n        \n        \n    \n        \n        \n        \n        \n        \n        \n        \n        \n    \n        \n        \n        \n        \n        \n        \n        \n        \n    \n        \n        \n        \n        \n        \n        \n        \n        \n    \n        \n        \n        \n        \n        \n        \n        \n        \n        \n    \n        \n        \n        \n        \n        \n        \n        \n        \n    \n        \n        \n        \n        \n        \n        \n        \n        \n    \n        \n        \n        \n        \n        \n        \n        \n        \n        \n    \n        \n        \n        \n        \n        \n        \n        \n        \n    \n        \n        \n        ', 'error_type': 'json_parse_error', 'error_message': "Expecting ':' delimiter: line 133 column 9 (char 1414)"}
# Task 60b61512:
#   31/128 invalid
#   0.24 invalid ratio
#   29/31 repaired
# Task 6150a2bd:
#   15/128 invalid
#   0.12 invalid ratio
#   14/15 repaired
# Task 63613498:
#   17/128 invalid
#   0.13 invalid ratio
#   17/17 repaired
# Task 6455b5f5:
#   22/128 invalid
#   0.17 invalid ratio
#   21/22 repaired
# Task 67385a82:
#   16/128 invalid
#   0.12 invalid ratio
#   16/16 repaired
# Task 67a3c6ac:
#   14/128 invalid
#   0.11 invalid ratio
#   14/14 repaired
# Task 67a423a3:
#   25/128 invalid
#   0.20 invalid ratio
#   25/25 repaired
# Task 6855a6e4:
#   19/128 invalid
#   0.15 invalid ratio
#   19/19 repaired
# Task 68b16354:
#   20/128 invalid
#   0.16 invalid ratio
#   19/20 repaired
# Task 694f12f3:
#   47/128 invalid
#   0.37 invalid ratio
#   45/47 repaired
# Task 6a1e5592:
#   18/128 invalid
#   0.14 invalid ratio
#   18/18 repaired
# Task 6aa20dc0:
#   15/128 invalid
#   0.12 invalid ratio
#   15/15 repaired
# Task 6c434453:
#   22/128 invalid
#   0.17 invalid ratio
#   21/22 repaired
# Task 6d58a25d:
#   17/128 invalid
#   0.13 invalid ratio
#   16/17 repaired
# Task 6d75e8bb:
#   25/128 invalid
#   0.20 invalid ratio
#   23/25 repaired
# Task 6e82a1ae:
#   16/128 invalid
#   0.12 invalid ratio
#   16/16 repaired
# Task 72322fa7:
#   25/128 invalid
#   0.20 invalid ratio
#   24/25 repaired
# Task 7447852a:
#   21/128 invalid
#   0.16 invalid ratio
#   20/21 repaired
# Task 74dd1130:
#   18/128 invalid
#   0.14 invalid ratio
#   18/18 repaired
# Task 776ffc46:
#   22/128 invalid
#   0.17 invalid ratio
#   21/22 repaired
# Task 794b24be:
#   5/128 invalid
#   0.04 invalid ratio
#   5/5 repaired
# Task 7b6016b9:
#   15/128 invalid
#   0.12 invalid ratio
#   15/15 repaired
# Task 7ddcd7ec:
#   24/128 invalid
#   0.19 invalid ratio
#   23/24 repaired
# {
#     "per_task": {
#         "00d62c1b": {
#             "n_total": 128,
#             "n_invalid": 14,
#             "invalid_ratio": 0.109375,
#             "n_repaired": 13,
#             "cummulative_counts": [
#                 {
#                     "color_of": 2,
#                     "other": 5,
#                     "column_of": 2,
#                     "this": 4,
#                     "neighbor_of": 1,
#                     "color_equals": 2,
#                     "A": 2,
#                     "column_equals": 1,
#                     "and": 2,
#                     "direction_of": 1,
#                     "move_node_max": 1,
#                     "vars": 1,
#                     "filter": 1,
#                     "apply": 1,
#                     "rule": 1,
#                     "do": 1
#                 },
#                 {
#                     "color_of": 4,
#                     "other": 10,
#                     "column_of": 4,
#                     "this": 8,
#                     "neighbor_of": 2,
#                     "color_equals": 4,
#                     "A": 4,
#                     "column_equals": 2,
#                     "and": 4,
#                     "direction_of": 2,
#                     "move_node_max": 2,
#                     "vars": 2,
#                     "filter": 2,
#                     "apply": 2,
#                     "rule": 2,
#                     "do": 2
#                 },
#                 {
#                     "color_of": 6,
#                     "other": 15,
#                     "column_of": 6,
#                     "this": 12,
#                     "neighbor_of": 3,
#                     "color_equals": 6,
#                     "A": 6,
#                     "column_equals": 3,
#                     "and": 6,
#                     "direction_of": 3,
#                     "move_node_max": 3,
#                     "vars": 3,
#                     "filter": 3,
#                     "apply": 3,
#                     "rule": 3,
#                     "do": 3
#                 },
#                 {
#                     "color_of": 8,
#                     "other": 20,
#                     "column_of": 8,
#                     "this": 16,
#                     "neighbor_of": 4,
#                     "color_equals": 8,
#                     "A": 8,
#                     "column_equals": 4,
#                     "and": 8,
#                     "direction_of": 4,
#                     "move_node_max": 4,
#                     "vars": 4,
#                     "filter": 4,
#                     "apply": 4,
#                     "rule": 4,
#                     "do": 4
#                 },
#                 {
#                     "color_of": 10,
#                     "other": 25,
#                     "column_of": 10,
#                     "this": 20,
#                     "neighbor_of": 5,
#                     "color_equals": 10,
#                     "A": 10,
#                     "column_equals": 5,
#                     "and": 10,
#                     "direction_of": 5,
#                     "move_node_max": 5,
#                     "vars": 5,
#                     "filter": 5,
#                     "apply": 5,
#                     "rule": 5,
#                     "do": 5
#                 },
#                 {
#                     "color_of": 12,
#                     "other": 30,
#                     "column_of": 12,
#                     "this": 24,
#                     "neighbor_of": 6,
#                     "color_equals": 12,
#                     "A": 12,
#                     "column_equals": 6,
#                     "and": 12,
#                     "direction_of": 6,
#                     "move_node_max": 6,
#                     "vars": 6,
#                     "filter": 6,
#                     "apply": 6,
#                     "rule": 6,
#                     "do": 6
#                 },
#                 {
#                     "color_of": 14,
#                     "other": 35,
#                     "column_of": 14,
#                     "this": 28,
#                     "neighbor_of": 7,
#                     "color_equals": 14,
#                     "A": 14,
#                     "column_equals": 7,
#                     "and": 14,
#                     "direction_of": 7,
#                     "move_node_max": 7,
#                     "vars": 7,
#                     "filter": 7,
#                     "apply": 7,
#                     "rule": 7,
#                     "do": 7
#                 },
#                 {
#                     "color_of": 16,
#                     "other": 40,
#                     "column_of": 16,
#                     "this": 32,
#                     "neighbor_of": 8,
#                     "color_equals": 16,
#                     "A": 16,
#                     "column_equals": 8,
#                     "and": 16,
#                     "direction_of": 8,
#                     "move_node_max": 8,
#                     "vars": 8,
#                     "filter": 8,
#                     "apply": 8,
#                     "rule": 8,
#                     "do": 8
#                 },
#                 {
#                     "color_of": 18,
#                     "other": 45,
#                     "column_of": 18,
#                     "this": 36,
#                     "neighbor_of": 9,
#                     "color_equals": 18,
#                     "A": 18,
#                     "column_equals": 9,
#                     "and": 18,
#                     "direction_of": 9,
#                     "move_node_max": 9,
#                     "vars": 9,
#                     "filter": 9,
#                     "apply": 9,
#                     "rule": 9,
#                     "do": 9
#                 },
#                 {
#                     "color_of": 20,
#                     "other": 50,
#                     "column_of": 20,
#                     "this": 40,
#                     "neighbor_of": 10,
#                     "color_equals": 20,
#                     "A": 20,
#                     "column_equals": 10,
#                     "and": 20,
#                     "direction_of": 10,
#                     "move_node_max": 10,
#                     "vars": 10,
#                     "filter": 10,
#                     "apply": 10,
#                     "rule": 10,
#                     "do": 10
#                 },
#                 {
#                     "color_of": 22,
#                     "other": 55,
#                     "column_of": 22,
#                     "this": 44,
#                     "neighbor_of": 11,
#                     "color_equals": 22,
#                     "A": 22,
#                     "column_equals": 11,
#                     "and": 22,
#                     "direction_of": 11,
#                     "move_node_max": 11,
#                     "vars": 11,
#                     "filter": 11,
#                     "apply": 11,
#                     "rule": 11,
#                     "do": 11
#                 },
#                 {
#                     "color_of": 24,
#                     "other": 60,
#                     "column_of": 24,
#                     "this": 48,
#                     "neighbor_of": 12,
#                     "color_equals": 24,
#                     "A": 24,
#                     "column_equals": 12,
#                     "and": 24,
#                     "direction_of": 12,
#                     "move_node_max": 12,
#                     "vars": 12,
#                     "filter": 12,
#                     "apply": 12,
#                     "rule": 12,
#                     "do": 12
#                 },
#                 {
#                     "color_of": 26,
#                     "other": 65,
#                     "column_of": 26,
#                     "this": 52,
#                     "neighbor_of": 13,
#                     "color_equals": 26,
#                     "A": 26,
#                     "column_equals": 13,
#                     "and": 26,
#                     "direction_of": 13,
#                     "move_node_max": 13,
#                     "vars": 13,
#                     "filter": 13,
#                     "apply": 13,
#                     "rule": 13,
#                     "do": 13
#                 }
#             ]
#         },
#         "025d127b": {
#             "n_total": 128,
#             "n_invalid": 17,
#             "invalid_ratio": 0.1328125,
#             "n_repaired": 16,
#             "cummulative_counts": [
#                 {
#                     "color_of": 2,
#                     "other": 5,
#                     "column_of": 2,
#                     "this": 4,
#                     "neighbor_of": 1,
#                     "color_equals": 2,
#                     "A": 2,
#                     "column_equals": 1,
#                     "and": 2,
#                     "direction_of": 1,
#                     "move_node_max": 1,
#                     "vars": 1,
#                     "filter": 1,
#                     "apply": 1,
#                     "rule": 1,
#                     "do": 1
#                 },
#                 {
#                     "color_of": 4,
#                     "other": 10,
#                     "column_of": 4,
#                     "this": 8,
#                     "neighbor_of": 2,
#                     "color_equals": 4,
#                     "A": 4,
#                     "column_equals": 2,
#                     "and": 4,
#                     "direction_of": 2,
#                     "move_node_max": 2,
#                     "vars": 2,
#                     "filter": 2,
#                     "apply": 2,
#                     "rule": 2,
#                     "do": 2
#                 },
#                 {
#                     "color_of": 6,
#                     "other": 15,
#                     "column_of": 6,
#                     "this": 12,
#                     "neighbor_of": 3,
#                     "color_equals": 6,
#                     "A": 6,
#                     "column_equals": 3,
#                     "and": 6,
#                     "direction_of": 3,
#                     "move_node_max": 3,
#                     "vars": 3,
#                     "filter": 3,
#                     "apply": 3,
#                     "rule": 3,
#                     "do": 3
#                 },
#                 {
#                     "color_of": 8,
#                     "other": 20,
#                     "column_of": 8,
#                     "this": 16,
#                     "neighbor_of": 4,
#                     "color_equals": 8,
#                     "A": 8,
#                     "column_equals": 4,
#                     "and": 8,
#                     "direction_of": 4,
#                     "move_node_max": 4,
#                     "vars": 4,
#                     "filter": 4,
#                     "apply": 4,
#                     "rule": 4,
#                     "do": 4
#                 },
#                 {
#                     "color_of": 10,
#                     "other": 25,
#                     "column_of": 10,
#                     "this": 20,
#                     "neighbor_of": 5,
#                     "color_equals": 10,
#                     "A": 10,
#                     "column_equals": 5,
#                     "and": 10,
#                     "direction_of": 5,
#                     "move_node_max": 5,
#                     "vars": 5,
#                     "filter": 5,
#                     "apply": 5,
#                     "rule": 5,
#                     "do": 5
#                 },
#                 {
#                     "color_of": 12,
#                     "other": 30,
#                     "column_of": 12,
#                     "this": 24,
#                     "neighbor_of": 6,
#                     "color_equals": 12,
#                     "A": 12,
#                     "column_equals": 6,
#                     "and": 12,
#                     "direction_of": 6,
#                     "move_node_max": 6,
#                     "vars": 6,
#                     "filter": 6,
#                     "apply": 6,
#                     "rule": 6,
#                     "do": 6
#                 },
#                 {
#                     "color_of": 14,
#                     "other": 35,
#                     "column_of": 14,
#                     "this": 28,
#                     "neighbor_of": 7,
#                     "color_equals": 14,
#                     "A": 14,
#                     "column_equals": 7,
#                     "and": 14,
#                     "direction_of": 7,
#                     "move_node_max": 7,
#                     "vars": 7,
#                     "filter": 7,
#                     "apply": 7,
#                     "rule": 7,
#                     "do": 7
#                 },
#                 {
#                     "color_of": 16,
#                     "other": 40,
#                     "column_of": 16,
#                     "this": 32,
#                     "neighbor_of": 8,
#                     "color_equals": 16,
#                     "A": 16,
#                     "column_equals": 8,
#                     "and": 16,
#                     "direction_of": 8,
#                     "move_node_max": 8,
#                     "vars": 8,
#                     "filter": 8,
#                     "apply": 8,
#                     "rule": 8,
#                     "do": 8
#                 },
#                 {
#                     "color_of": 18,
#                     "other": 45,
#                     "column_of": 18,
#                     "this": 36,
#                     "neighbor_of": 9,
#                     "color_equals": 18,
#                     "A": 18,
#                     "column_equals": 9,
#                     "and": 18,
#                     "direction_of": 9,
#                     "move_node_max": 9,
#                     "vars": 9,
#                     "filter": 9,
#                     "apply": 9,
#                     "rule": 9,
#                     "do": 9
#                 },
#                 {
#                     "color_of": 20,
#                     "other": 50,
#                     "column_of": 20,
#                     "this": 40,
#                     "neighbor_of": 10,
#                     "color_equals": 20,
#                     "A": 20,
#                     "column_equals": 10,
#                     "and": 20,
#                     "direction_of": 10,
#                     "move_node_max": 10,
#                     "vars": 10,
#                     "filter": 10,
#                     "apply": 10,
#                     "rule": 10,
#                     "do": 10
#                 },
#                 {
#                     "color_of": 22,
#                     "other": 55,
#                     "column_of": 22,
#                     "this": 44,
#                     "neighbor_of": 11,
#                     "color_equals": 22,
#                     "A": 22,
#                     "column_equals": 11,
#                     "and": 22,
#                     "direction_of": 11,
#                     "move_node_max": 11,
#                     "vars": 11,
#                     "filter": 11,
#                     "apply": 11,
#                     "rule": 11,
#                     "do": 11
#                 },
#                 {
#                     "color_of": 24,
#                     "other": 60,
#                     "column_of": 24,
#                     "this": 48,
#                     "neighbor_of": 12,
#                     "color_equals": 24,
#                     "A": 24,
#                     "column_equals": 12,
#                     "and": 24,
#                     "direction_of": 12,
#                     "move_node_max": 12,
#                     "vars": 12,
#                     "filter": 12,
#                     "apply": 12,
#                     "rule": 12,
#                     "do": 12
#                 },
#                 {
#                     "color_of": 26,
#                     "other": 65,
#                     "column_of": 26,
#                     "this": 52,
#                     "neighbor_of": 13,
#                     "color_equals": 26,
#                     "A": 26,
#                     "column_equals": 13,
#                     "and": 26,
#                     "direction_of": 13,
#                     "move_node_max": 13,
#                     "vars": 13,
#                     "filter": 13,
#                     "apply": 13,
#                     "rule": 13,
#                     "do": 13
#                 },
#                 {
#                     "color_of": 28,
#                     "other": 70,
#                     "column_of": 28,
#                     "this": 56,
#                     "neighbor_of": 14,
#                     "color_equals": 28,
#                     "A": 28,
#                     "column_equals": 14,
#                     "and": 28,
#                     "direction_of": 14,
#                     "move_node_max": 14,
#                     "vars": 14,
#                     "filter": 14,
#                     "apply": 14,
#                     "rule": 14,
#                     "do": 14
#                 },
#                 {
#                     "color_of": 30,
#                     "other": 75,
#                     "column_of": 30,
#                     "this": 60,
#                     "neighbor_of": 15,
#                     "color_equals": 30,
#                     "A": 30,
#                     "column_equals": 15,
#                     "and": 30,
#                     "direction_of": 15,
#                     "move_node_max": 15,
#                     "vars": 15,
#                     "filter": 15,
#                     "apply": 15,
#                     "rule": 15,
#                     "do": 15
#                 },
#                 {
#                     "color_of": 32,
#                     "other": 80,
#                     "column_of": 32,
#                     "this": 64,
#                     "neighbor_of": 16,
#                     "color_equals": 32,
#                     "A": 32,
#                     "column_equals": 16,
#                     "and": 32,
#                     "direction_of": 16,
#                     "move_node_max": 16,
#                     "vars": 16,
#                     "filter": 16,
#                     "apply": 16,
#                     "rule": 16,
#                     "do": 16
#                 }
#             ]
#         },
#         "05f2a901": {
#             "n_total": 128,
#             "n_invalid": 18,
#             "invalid_ratio": 0.140625,
#             "n_repaired": 18,
#             "cummulative_counts": [
#                 {
#                     "color_of": 2,
#                     "other": 5,
#                     "column_of": 2,
#                     "this": 4,
#                     "neighbor_of": 1,
#                     "color_equals": 2,
#                     "A": 2,
#                     "column_equals": 1,
#                     "and": 2,
#                     "direction_of": 1,
#                     "move_node_max": 1,
#                     "vars": 1,
#                     "filter": 1,
#                     "apply": 1,
#                     "rule": 1,
#                     "do": 1
#                 },
#                 {
#                     "color_of": 4,
#                     "other": 10,
#                     "column_of": 4,
#                     "this": 8,
#                     "neighbor_of": 2,
#                     "color_equals": 4,
#                     "A": 4,
#                     "column_equals": 2,
#                     "and": 4,
#                     "direction_of": 2,
#                     "move_node_max": 2,
#                     "vars": 2,
#                     "filter": 2,
#                     "apply": 2,
#                     "rule": 2,
#                     "do": 2
#                 },
#                 {
#                     "color_of": 6,
#                     "other": 15,
#                     "column_of": 6,
#                     "this": 12,
#                     "neighbor_of": 3,
#                     "color_equals": 6,
#                     "A": 6,
#                     "column_equals": 3,
#                     "and": 6,
#                     "direction_of": 3,
#                     "move_node_max": 3,
#                     "vars": 3,
#                     "filter": 3,
#                     "apply": 3,
#                     "rule": 3,
#                     "do": 3
#                 },
#                 {
#                     "color_of": 8,
#                     "other": 20,
#                     "column_of": 8,
#                     "this": 16,
#                     "neighbor_of": 4,
#                     "color_equals": 8,
#                     "A": 8,
#                     "column_equals": 4,
#                     "and": 8,
#                     "direction_of": 4,
#                     "move_node_max": 4,
#                     "vars": 4,
#                     "filter": 4,
#                     "apply": 4,
#                     "rule": 4,
#                     "do": 4
#                 },
#                 {
#                     "color_of": 10,
#                     "other": 25,
#                     "column_of": 10,
#                     "this": 20,
#                     "neighbor_of": 5,
#                     "color_equals": 10,
#                     "A": 10,
#                     "column_equals": 5,
#                     "and": 10,
#                     "direction_of": 5,
#                     "move_node_max": 5,
#                     "vars": 5,
#                     "filter": 5,
#                     "apply": 5,
#                     "rule": 5,
#                     "do": 5
#                 },
#                 {
#                     "color_of": 12,
#                     "other": 30,
#                     "column_of": 12,
#                     "this": 24,
#                     "neighbor_of": 6,
#                     "color_equals": 12,
#                     "A": 12,
#                     "column_equals": 6,
#                     "and": 12,
#                     "direction_of": 6,
#                     "move_node_max": 6,
#                     "vars": 6,
#                     "filter": 6,
#                     "apply": 6,
#                     "rule": 6,
#                     "do": 6
#                 },
#                 {
#                     "color_of": 14,
#                     "other": 35,
#                     "column_of": 14,
#                     "this": 28,
#                     "neighbor_of": 7,
#                     "color_equals": 14,
#                     "A": 14,
#                     "column_equals": 7,
#                     "and": 14,
#                     "direction_of": 7,
#                     "move_node_max": 7,
#                     "vars": 7,
#                     "filter": 7,
#                     "apply": 7,
#                     "rule": 7,
#                     "do": 7
#                 },
#                 {
#                     "color_of": 16,
#                     "other": 40,
#                     "column_of": 16,
#                     "this": 32,
#                     "neighbor_of": 8,
#                     "color_equals": 16,
#                     "A": 16,
#                     "column_equals": 8,
#                     "and": 16,
#                     "direction_of": 8,
#                     "move_node_max": 8,
#                     "vars": 8,
#                     "filter": 8,
#                     "apply": 8,
#                     "rule": 8,
#                     "do": 8
#                 },
#                 {
#                     "color_of": 18,
#                     "other": 45,
#                     "column_of": 18,
#                     "this": 36,
#                     "neighbor_of": 9,
#                     "color_equals": 18,
#                     "A": 18,
#                     "column_equals": 9,
#                     "and": 18,
#                     "direction_of": 9,
#                     "move_node_max": 9,
#                     "vars": 9,
#                     "filter": 9,
#                     "apply": 9,
#                     "rule": 9,
#                     "do": 9
#                 },
#                 {
#                     "color_of": 20,
#                     "other": 50,
#                     "column_of": 20,
#                     "this": 40,
#                     "neighbor_of": 10,
#                     "color_equals": 20,
#                     "A": 20,
#                     "column_equals": 10,
#                     "and": 20,
#                     "direction_of": 10,
#                     "move_node_max": 10,
#                     "vars": 10,
#                     "filter": 10,
#                     "apply": 10,
#                     "rule": 10,
#                     "do": 10
#                 },
#                 {
#                     "color_of": 22,
#                     "other": 55,
#                     "column_of": 22,
#                     "this": 44,
#                     "neighbor_of": 11,
#                     "color_equals": 22,
#                     "A": 22,
#                     "column_equals": 11,
#                     "and": 22,
#                     "direction_of": 11,
#                     "move_node_max": 11,
#                     "vars": 11,
#                     "filter": 11,
#                     "apply": 11,
#                     "rule": 11,
#                     "do": 11
#                 },
#                 {
#                     "color_of": 24,
#                     "other": 60,
#                     "column_of": 24,
#                     "this": 48,
#                     "neighbor_of": 12,
#                     "color_equals": 24,
#                     "A": 24,
#                     "column_equals": 12,
#                     "and": 24,
#                     "direction_of": 12,
#                     "move_node_max": 12,
#                     "vars": 12,
#                     "filter": 12,
#                     "apply": 12,
#                     "rule": 12,
#                     "do": 12
#                 },
#                 {
#                     "color_of": 26,
#                     "other": 65,
#                     "column_of": 26,
#                     "this": 52,
#                     "neighbor_of": 13,
#                     "color_equals": 26,
#                     "A": 26,
#                     "column_equals": 13,
#                     "and": 26,
#                     "direction_of": 13,
#                     "move_node_max": 13,
#                     "vars": 13,
#                     "filter": 13,
#                     "apply": 13,
#                     "rule": 13,
#                     "do": 13
#                 },
#                 {
#                     "color_of": 28,
#                     "other": 70,
#                     "column_of": 28,
#                     "this": 56,
#                     "neighbor_of": 14,
#                     "color_equals": 28,
#                     "A": 28,
#                     "column_equals": 14,
#                     "and": 28,
#                     "direction_of": 14,
#                     "move_node_max": 14,
#                     "vars": 14,
#                     "filter": 14,
#                     "apply": 14,
#                     "rule": 14,
#                     "do": 14
#                 },
#                 {
#                     "color_of": 30,
#                     "other": 75,
#                     "column_of": 30,
#                     "this": 60,
#                     "neighbor_of": 15,
#                     "color_equals": 30,
#                     "A": 30,
#                     "column_equals": 15,
#                     "and": 30,
#                     "direction_of": 15,
#                     "move_node_max": 15,
#                     "vars": 15,
#                     "filter": 15,
#                     "apply": 15,
#                     "rule": 15,
#                     "do": 15
#                 },
#                 {
#                     "color_of": 32,
#                     "other": 80,
#                     "column_of": 32,
#                     "this": 64,
#                     "neighbor_of": 16,
#                     "color_equals": 32,
#                     "A": 32,
#                     "column_equals": 16,
#                     "and": 32,
#                     "direction_of": 16,
#                     "move_node_max": 16,
#                     "vars": 16,
#                     "filter": 16,
#                     "apply": 16,
#                     "rule": 16,
#                     "do": 16
#                 },
#                 {
#                     "color_of": 34,
#                     "other": 85,
#                     "column_of": 34,
#                     "this": 68,
#                     "neighbor_of": 17,
#                     "color_equals": 34,
#                     "A": 34,
#                     "column_equals": 17,
#                     "and": 34,
#                     "direction_of": 17,
#                     "move_node_max": 17,
#                     "vars": 17,
#                     "filter": 17,
#                     "apply": 17,
#                     "rule": 17,
#                     "do": 17
#                 },
#                 {
#                     "color_of": 36,
#                     "other": 90,
#                     "column_of": 36,
#                     "this": 72,
#                     "neighbor_of": 18,
#                     "color_equals": 36,
#                     "A": 36,
#                     "column_equals": 18,
#                     "and": 36,
#                     "direction_of": 18,
#                     "move_node_max": 18,
#                     "vars": 18,
#                     "filter": 18,
#                     "apply": 18,
#                     "rule": 18,
#                     "do": 18
#                 }
#             ]
#         },
#         "08ed6ac7": {
#             "n_total": 128,
#             "n_invalid": 35,
#             "invalid_ratio": 0.2734375,
#             "n_repaired": 34,
#             "cummulative_counts": [
#                 {
#                     "color_of": 2,
#                     "other": 5,
#                     "column_of": 2,
#                     "this": 4,
#                     "neighbor_of": 1,
#                     "color_equals": 2,
#                     "A": 2,
#                     "column_equals": 1,
#                     "and": 2,
#                     "direction_of": 1,
#                     "move_node_max": 1,
#                     "vars": 1,
#                     "filter": 1,
#                     "apply": 1,
#                     "rule": 1,
#                     "do": 1
#                 },
#                 {
#                     "color_of": 4,
#                     "other": 10,
#                     "column_of": 4,
#                     "this": 8,
#                     "neighbor_of": 2,
#                     "color_equals": 4,
#                     "A": 4,
#                     "column_equals": 2,
#                     "and": 4,
#                     "direction_of": 2,
#                     "move_node_max": 2,
#                     "vars": 2,
#                     "filter": 2,
#                     "apply": 2,
#                     "rule": 2,
#                     "do": 2
#                 },
#                 {
#                     "color_of": 6,
#                     "other": 15,
#                     "column_of": 6,
#                     "this": 12,
#                     "neighbor_of": 3,
#                     "color_equals": 6,
#                     "A": 6,
#                     "column_equals": 3,
#                     "and": 6,
#                     "direction_of": 3,
#                     "move_node_max": 3,
#                     "vars": 3,
#                     "filter": 3,
#                     "apply": 3,
#                     "rule": 3,
#                     "do": 3
#                 },
#                 {
#                     "color_of": 8,
#                     "other": 20,
#                     "column_of": 8,
#                     "this": 16,
#                     "neighbor_of": 4,
#                     "color_equals": 8,
#                     "A": 8,
#                     "column_equals": 4,
#                     "and": 8,
#                     "direction_of": 4,
#                     "move_node_max": 4,
#                     "vars": 4,
#                     "filter": 4,
#                     "apply": 4,
#                     "rule": 4,
#                     "do": 4
#                 },
#                 {
#                     "color_of": 10,
#                     "other": 25,
#                     "column_of": 10,
#                     "this": 20,
#                     "neighbor_of": 5,
#                     "color_equals": 10,
#                     "A": 10,
#                     "column_equals": 5,
#                     "and": 10,
#                     "direction_of": 5,
#                     "move_node_max": 5,
#                     "vars": 5,
#                     "filter": 5,
#                     "apply": 5,
#                     "rule": 5,
#                     "do": 5
#                 },
#                 {
#                     "color_of": 12,
#                     "other": 30,
#                     "column_of": 12,
#                     "this": 24,
#                     "neighbor_of": 6,
#                     "color_equals": 12,
#                     "A": 12,
#                     "column_equals": 6,
#                     "and": 12,
#                     "direction_of": 6,
#                     "move_node_max": 6,
#                     "vars": 6,
#                     "filter": 6,
#                     "apply": 6,
#                     "rule": 6,
#                     "do": 6
#                 },
#                 {
#                     "color_of": 14,
#                     "other": 35,
#                     "column_of": 14,
#                     "this": 28,
#                     "neighbor_of": 7,
#                     "color_equals": 14,
#                     "A": 14,
#                     "column_equals": 7,
#                     "and": 14,
#                     "direction_of": 7,
#                     "move_node_max": 7,
#                     "vars": 7,
#                     "filter": 7,
#                     "apply": 7,
#                     "rule": 7,
#                     "do": 7
#                 },
#                 {
#                     "color_of": 16,
#                     "other": 40,
#                     "column_of": 16,
#                     "this": 32,
#                     "neighbor_of": 8,
#                     "color_equals": 16,
#                     "A": 16,
#                     "column_equals": 8,
#                     "and": 16,
#                     "direction_of": 8,
#                     "move_node_max": 8,
#                     "vars": 8,
#                     "filter": 8,
#                     "apply": 8,
#                     "rule": 8,
#                     "do": 8
#                 },
#                 {
#                     "color_of": 18,
#                     "other": 45,
#                     "column_of": 18,
#                     "this": 36,
#                     "neighbor_of": 9,
#                     "color_equals": 18,
#                     "A": 18,
#                     "column_equals": 9,
#                     "and": 18,
#                     "direction_of": 9,
#                     "move_node_max": 9,
#                     "vars": 9,
#                     "filter": 9,
#                     "apply": 9,
#                     "rule": 9,
#                     "do": 9
#                 },
#                 {
#                     "color_of": 20,
#                     "other": 50,
#                     "column_of": 20,
#                     "this": 40,
#                     "neighbor_of": 10,
#                     "color_equals": 20,
#                     "A": 20,
#                     "column_equals": 10,
#                     "and": 20,
#                     "direction_of": 10,
#                     "move_node_max": 10,
#                     "vars": 10,
#                     "filter": 10,
#                     "apply": 10,
#                     "rule": 10,
#                     "do": 10
#                 },
#                 {
#                     "color_of": 22,
#                     "other": 55,
#                     "column_of": 22,
#                     "this": 44,
#                     "neighbor_of": 11,
#                     "color_equals": 22,
#                     "A": 22,
#                     "column_equals": 11,
#                     "and": 22,
#                     "direction_of": 11,
#                     "move_node_max": 11,
#                     "vars": 11,
#                     "filter": 11,
#                     "apply": 11,
#                     "rule": 11,
#                     "do": 11
#                 },
#                 {
#                     "color_of": 24,
#                     "other": 60,
#                     "column_of": 24,
#                     "this": 48,
#                     "neighbor_of": 12,
#                     "color_equals": 24,
#                     "A": 24,
#                     "column_equals": 12,
#                     "and": 24,
#                     "direction_of": 12,
#                     "move_node_max": 12,
#                     "vars": 12,
#                     "filter": 12,
#                     "apply": 12,
#                     "rule": 12,
#                     "do": 12
#                 },
#                 {
#                     "color_of": 26,
#                     "other": 65,
#                     "column_of": 26,
#                     "this": 52,
#                     "neighbor_of": 13,
#                     "color_equals": 26,
#                     "A": 26,
#                     "column_equals": 13,
#                     "and": 26,
#                     "direction_of": 13,
#                     "move_node_max": 13,
#                     "vars": 13,
#                     "filter": 13,
#                     "apply": 13,
#                     "rule": 13,
#                     "do": 13
#                 },
#                 {
#                     "color_of": 28,
#                     "other": 70,
#                     "column_of": 28,
#                     "this": 56,
#                     "neighbor_of": 14,
#                     "color_equals": 28,
#                     "A": 28,
#                     "column_equals": 14,
#                     "and": 28,
#                     "direction_of": 14,
#                     "move_node_max": 14,
#                     "vars": 14,
#                     "filter": 14,
# ...
#                     "move_node_max": 12,
#                     "vars": 12,
#                     "filter": 12,
#                     "apply": 12,
#                     "rule": 12,
#                     "do": 12
#                 },
#                 {
#                     "color_of": 26,
#                     "other": 65,
#                     "column_of": 26,
#                     "this": 52,
#                     "neighbor_of": 13,
#                     "color_equals": 26,
#                     "A": 26,
#                     "column_equals": 13,
#                     "and": 26,
#                     "direction_of": 13,
#                     "move_node_max": 13,
#                     "vars": 13,
#                     "filter": 13,
#                     "apply": 13,
#                     "rule": 13,
#                     "do": 13
#                 },
#                 {
#                     "color_of": 28,
#                     "other": 70,
#                     "column_of": 28,
#                     "this": 56,
#                     "neighbor_of": 14,
#                     "color_equals": 28,
#                     "A": 28,
#                     "column_equals": 14,
#                     "and": 28,
#                     "direction_of": 14,
#                     "move_node_max": 14,
#                     "vars": 14,
#                     "filter": 14,
#                     "apply": 14,
#                     "rule": 14,
#                     "do": 14
#                 },
#                 {
#                     "color_of": 30,
#                     "other": 75,
#                     "column_of": 30,
#                     "this": 60,
#                     "neighbor_of": 15,
#                     "color_equals": 30,
#                     "A": 30,
#                     "column_equals": 15,
#                     "and": 30,
#                     "direction_of": 15,
#                     "move_node_max": 15,
#                     "vars": 15,
#                     "filter": 15,
#                     "apply": 15,
#                     "rule": 15,
#                     "do": 15
#                 }
#             ]
#         },
#         "7ddcd7ec": {
#             "n_total": 128,
#             "n_invalid": 24,
#             "invalid_ratio": 0.1875,
#             "n_repaired": 23,
#             "cummulative_counts": [
#                 {
#                     "color_of": 2,
#                     "other": 5,
#                     "column_of": 2,
#                     "this": 4,
#                     "neighbor_of": 1,
#                     "color_equals": 2,
#                     "A": 2,
#                     "column_equals": 1,
#                     "and": 2,
#                     "direction_of": 1,
#                     "move_node_max": 1,
#                     "vars": 1,
#                     "filter": 1,
#                     "apply": 1,
#                     "rule": 1,
#                     "do": 1
#                 },
#                 {
#                     "color_of": 4,
#                     "other": 10,
#                     "column_of": 4,
#                     "this": 8,
#                     "neighbor_of": 2,
#                     "color_equals": 4,
#                     "A": 4,
#                     "column_equals": 2,
#                     "and": 4,
#                     "direction_of": 2,
#                     "move_node_max": 2,
#                     "vars": 2,
#                     "filter": 2,
#                     "apply": 2,
#                     "rule": 2,
#                     "do": 2
#                 },
#                 {
#                     "color_of": 6,
#                     "other": 15,
#                     "column_of": 6,
#                     "this": 12,
#                     "neighbor_of": 3,
#                     "color_equals": 6,
#                     "A": 6,
#                     "column_equals": 3,
#                     "and": 6,
#                     "direction_of": 3,
#                     "move_node_max": 3,
#                     "vars": 3,
#                     "filter": 3,
#                     "apply": 3,
#                     "rule": 3,
#                     "do": 3
#                 },
#                 {
#                     "color_of": 8,
#                     "other": 20,
#                     "column_of": 8,
#                     "this": 16,
#                     "neighbor_of": 4,
#                     "color_equals": 8,
#                     "A": 8,
#                     "column_equals": 4,
#                     "and": 8,
#                     "direction_of": 4,
#                     "move_node_max": 4,
#                     "vars": 4,
#                     "filter": 4,
#                     "apply": 4,
#                     "rule": 4,
#                     "do": 4
#                 },
#                 {
#                     "color_of": 10,
#                     "other": 25,
#                     "column_of": 10,
#                     "this": 20,
#                     "neighbor_of": 5,
#                     "color_equals": 10,
#                     "A": 10,
#                     "column_equals": 5,
#                     "and": 10,
#                     "direction_of": 5,
#                     "move_node_max": 5,
#                     "vars": 5,
#                     "filter": 5,
#                     "apply": 5,
#                     "rule": 5,
#                     "do": 5
#                 },
#                 {
#                     "color_of": 12,
#                     "other": 30,
#                     "column_of": 12,
#                     "this": 24,
#                     "neighbor_of": 6,
#                     "color_equals": 12,
#                     "A": 12,
#                     "column_equals": 6,
#                     "and": 12,
#                     "direction_of": 6,
#                     "move_node_max": 6,
#                     "vars": 6,
#                     "filter": 6,
#                     "apply": 6,
#                     "rule": 6,
#                     "do": 6
#                 },
#                 {
#                     "color_of": 14,
#                     "other": 35,
#                     "column_of": 14,
#                     "this": 28,
#                     "neighbor_of": 7,
#                     "color_equals": 14,
#                     "A": 14,
#                     "column_equals": 7,
#                     "and": 14,
#                     "direction_of": 7,
#                     "move_node_max": 7,
#                     "vars": 7,
#                     "filter": 7,
#                     "apply": 7,
#                     "rule": 7,
#                     "do": 7
#                 },
#                 {
#                     "color_of": 16,
#                     "other": 40,
#                     "column_of": 16,
#                     "this": 32,
#                     "neighbor_of": 8,
#                     "color_equals": 16,
#                     "A": 16,
#                     "column_equals": 8,
#                     "and": 16,
#                     "direction_of": 8,
#                     "move_node_max": 8,
#                     "vars": 8,
#                     "filter": 8,
#                     "apply": 8,
#                     "rule": 8,
#                     "do": 8
#                 },
#                 {
#                     "color_of": 18,
#                     "other": 45,
#                     "column_of": 18,
#                     "this": 36,
#                     "neighbor_of": 9,
#                     "color_equals": 18,
#                     "A": 18,
#                     "column_equals": 9,
#                     "and": 18,
#                     "direction_of": 9,
#                     "move_node_max": 9,
#                     "vars": 9,
#                     "filter": 9,
#                     "apply": 9,
#                     "rule": 9,
#                     "do": 9
#                 },
#                 {
#                     "color_of": 20,
#                     "other": 50,
#                     "column_of": 20,
#                     "this": 40,
#                     "neighbor_of": 10,
#                     "color_equals": 20,
#                     "A": 20,
#                     "column_equals": 10,
#                     "and": 20,
#                     "direction_of": 10,
#                     "move_node_max": 10,
#                     "vars": 10,
#                     "filter": 10,
#                     "apply": 10,
#                     "rule": 10,
#                     "do": 10
#                 },
#                 {
#                     "color_of": 22,
#                     "other": 55,
#                     "column_of": 22,
#                     "this": 44,
#                     "neighbor_of": 11,
#                     "color_equals": 22,
#                     "A": 22,
#                     "column_equals": 11,
#                     "and": 22,
#                     "direction_of": 11,
#                     "move_node_max": 11,
#                     "vars": 11,
#                     "filter": 11,
#                     "apply": 11,
#                     "rule": 11,
#                     "do": 11
#                 },
#                 {
#                     "color_of": 24,
#                     "other": 60,
#                     "column_of": 24,
#                     "this": 48,
#                     "neighbor_of": 12,
#                     "color_equals": 24,
#                     "A": 24,
#                     "column_equals": 12,
#                     "and": 24,
#                     "direction_of": 12,
#                     "move_node_max": 12,
#                     "vars": 12,
#                     "filter": 12,
#                     "apply": 12,
#                     "rule": 12,
#                     "do": 12
#                 },
#                 {
#                     "color_of": 26,
#                     "other": 65,
#                     "column_of": 26,
#                     "this": 52,
#                     "neighbor_of": 13,
#                     "color_equals": 26,
#                     "A": 26,
#                     "column_equals": 13,
#                     "and": 26,
#                     "direction_of": 13,
#                     "move_node_max": 13,
#                     "vars": 13,
#                     "filter": 13,
#                     "apply": 13,
#                     "rule": 13,
#                     "do": 13
#                 },
#                 {
#                     "color_of": 28,
#                     "other": 70,
#                     "column_of": 28,
#                     "this": 56,
#                     "neighbor_of": 14,
#                     "color_equals": 28,
#                     "A": 28,
#                     "column_equals": 14,
#                     "and": 28,
#                     "direction_of": 14,
#                     "move_node_max": 14,
#                     "vars": 14,
#                     "filter": 14,
#                     "apply": 14,
#                     "rule": 14,
#                     "do": 14
#                 },
#                 {
#                     "color_of": 30,
#                     "other": 75,
#                     "column_of": 30,
#                     "this": 60,
#                     "neighbor_of": 15,
#                     "color_equals": 30,
#                     "A": 30,
#                     "column_equals": 15,
#                     "and": 30,
#                     "direction_of": 15,
#                     "move_node_max": 15,
#                     "vars": 15,
#                     "filter": 15,
#                     "apply": 15,
#                     "rule": 15,
#                     "do": 15
#                 },
#                 {
#                     "color_of": 32,
#                     "other": 80,
#                     "column_of": 32,
#                     "this": 64,
#                     "neighbor_of": 16,
#                     "color_equals": 32,
#                     "A": 32,
#                     "column_equals": 16,
#                     "and": 32,
#                     "direction_of": 16,
#                     "move_node_max": 16,
#                     "vars": 16,
#                     "filter": 16,
#                     "apply": 16,
#                     "rule": 16,
#                     "do": 16
#                 },
#                 {
#                     "color_of": 34,
#                     "other": 85,
#                     "column_of": 34,
#                     "this": 68,
#                     "neighbor_of": 17,
#                     "color_equals": 34,
#                     "A": 34,
#                     "column_equals": 17,
#                     "and": 34,
#                     "direction_of": 17,
#                     "move_node_max": 17,
#                     "vars": 17,
#                     "filter": 17,
#                     "apply": 17,
#                     "rule": 17,
#                     "do": 17
#                 },
#                 {
#                     "color_of": 36,
#                     "other": 90,
#                     "column_of": 36,
#                     "this": 72,
#                     "neighbor_of": 18,
#                     "color_equals": 36,
#                     "A": 36,
#                     "column_equals": 18,
#                     "and": 36,
#                     "direction_of": 18,
#                     "move_node_max": 18,
#                     "vars": 18,
#                     "filter": 18,
#                     "apply": 18,
#                     "rule": 18,
#                     "do": 18
#                 },
#                 {
#                     "color_of": 38,
#                     "other": 95,
#                     "column_of": 38,
#                     "this": 76,
#                     "neighbor_of": 19,
#                     "color_equals": 38,
#                     "A": 38,
#                     "column_equals": 19,
#                     "and": 38,
#                     "direction_of": 19,
#                     "move_node_max": 19,
#                     "vars": 19,
#                     "filter": 19,
#                     "apply": 19,
#                     "rule": 19,
#                     "do": 19
#                 },
#                 {
#                     "color_of": 40,
#                     "other": 100,
#                     "column_of": 40,
#                     "this": 80,
#                     "neighbor_of": 20,
#                     "color_equals": 40,
#                     "A": 40,
#                     "column_equals": 20,
#                     "and": 40,
#                     "direction_of": 20,
#                     "move_node_max": 20,
#                     "vars": 20,
#                     "filter": 20,
#                     "apply": 20,
#                     "rule": 20,
#                     "do": 20
#                 },
#                 {
#                     "color_of": 42,
#                     "other": 105,
#                     "column_of": 42,
#                     "this": 84,
#                     "neighbor_of": 21,
#                     "color_equals": 42,
#                     "A": 42,
#                     "column_equals": 21,
#                     "and": 42,
#                     "direction_of": 21,
#                     "move_node_max": 21,
#                     "vars": 21,
#                     "filter": 21,
#                     "apply": 21,
#                     "rule": 21,
#                     "do": 21
#                 },
#                 {
#                     "color_of": 44,
#                     "other": 110,
#                     "column_of": 44,
#                     "this": 88,
#                     "neighbor_of": 22,
#                     "color_equals": 44,
#                     "A": 44,
#                     "column_equals": 22,
#                     "and": 44,
#                     "direction_of": 22,
#                     "move_node_max": 22,
#                     "vars": 22,
#                     "filter": 22,
#                     "apply": 22,
#                     "rule": 22,
#                     "do": 22
#                 },
#                 {
#                     "color_of": 46,
#                     "other": 115,
#                     "column_of": 46,
#                     "this": 92,
#                     "neighbor_of": 23,
#                     "color_equals": 46,
#                     "A": 46,
#                     "column_equals": 23,
#                     "and": 46,
#                     "direction_of": 23,
#                     "move_node_max": 23,
#                     "vars": 23,
#                     "filter": 23,
#                     "apply": 23,
#                     "rule": 23,
#                     "do": 23
#                 }
#             ]
#         }
#     },
#     "all": {
#         "n_total": 10240,
#         "n_invalid": 1676,
#         "invalid_ratio": 0.163671875,
#         "n_repaired": 1632
#     }
# }
