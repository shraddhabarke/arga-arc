# %%
import lark
from lark import Lark, Transformer, v_args, Visitor
from collections import Counter
import json
import numpy as np

# %%
sexpr_grammar_path = "dsl/sexpr.lark"
sexpr_grammar = open(sexpr_grammar_path).read()
sexpr_parser = Lark(sexpr_grammar, start='sexpr')

# This visitor computes a map with the number of times each atom appears in the S-Expression
class SExprStats(Visitor):
    def __init__(self) -> None:
        super().__init__()
        self.counts = Counter()

    def atom(self, atom):
        name = atom.children[0].value
        self.counts[name] += 1

# %%
sexpr_example = """
(
    (a 1)
    (
        (b 2)
        (a 3)
    )
)
"""
sexpr_tree = sexpr_parser.parse(sexpr_example)
print(sexpr_tree.pretty())

stats = SExprStats()
stats.visit(sexpr_tree)
print(stats.counts)
# Out:
# sexpr
#   sexpr
#     sexpr
#       atom	a
#     sexpr
#       atom	1
#   sexpr
#     sexpr
#       sexpr
#         atom	b
#       sexpr
#         atom	2
#     sexpr
#       sexpr
#         atom	a
#       sexpr
#         atom	3
#
# Counter({'a': 2, 'b': 1, '2': 1, '3': 1, '1': 1})

# %%
def parse_entry(entry):
    task_id, valid, invalid = entry
    task_id = task_id.split(" ")[1]
    valid = int(valid.split(": ")[1])
    invalid = int(invalid.split(": ")[1])

    return task_id, valid, invalid

def parse_log(log_path):
    with open(log_path, "r") as f:
        log = f.read()

    log = log.splitlines()
    header = log[:3]
    log = log[3:]

    model = header[1].split(": ")[1]
    num_gens = int(header[2].split(": ")[1])

    assert len(log) % 3 == 0

    log = list(zip(*[iter(log)]*3))
    log = [parse_entry(entry) for entry in log]

    return model, num_gens, log

def try_parse_sexpr(code):
    try:
        code_tree = sexpr_parser.parse(code)
        return code , "valid", code_tree
    except Exception as e:
        # print(e)
        pass
    rep_code = "(" + code
    try:
        code_tree = sexpr_parser.parse(rep_code)
        return rep_code, "paren_l", code_tree
    except Exception as e:
        # print(e)
        pass
    rep_code = code + ")"
    try:
        code_tree = sexpr_parser.parse(rep_code)
        return rep_code, "paren_r", code_tree
    except Exception as e:
        # print(e)
        pass
    return code, "invalid", None

# gens_path = "dsl/v0_3/generations/gens_test"
gens_path = "dsl/v0_3/generations/arga_gpt4o_m100_20240516"

# read the log file
with open(gens_path + "/log.txt") as f:
    log = f.read()

# parse the log file
model, num_gens, log = parse_log(gens_path + "/log.txt")
print(model, num_gens)

all_tasks_count = {}

# log = log[:1]
print(len(log))
for task_id, n_valid, n_invalid in log:
    valid_file = gens_path + f"/{task_id}_valid.txt"
    invalid_file = gens_path + f"/{task_id}_invalid.txt"

    with open(valid_file, "r") as f:
        valid = json.load(f)
    with open(invalid_file, "r") as f:
        invalid = json.load(f)

    all = []
    for entry in valid:
        response = json.loads(entry)
        all.append(response["code"])
    for entry in invalid:
        response = json.loads(entry["response"])
        all.append(response["code"])
    # print(f"Task {task_id}: {n_valid} valid, {n_invalid} invalid")
    print(f"Task {task_id}:")
    assert n_valid + n_invalid == len(all)
    print(f"{len(valid)}/{len(all)} valid")
    # lib = f"(\n{''.join(all)}\n)"
    #parse the library
    # lib_tree = sexpr_parser.parse(lib)
    global_counter = Counter()
    task_stats = {
        # "task_id": task_id,
        "per_solution_counts": []
    }
    emp_valid = 0
    repaired = 0
    skipped = 0
    for code in all:
        # print(code)
        code, parse_status, code_tree = try_parse_sexpr(code)
        if parse_status == "invalid":
            skipped += 1
            continue
        elif parse_status != "valid":
            repaired += 1
        elif parse_status == "valid":
            emp_valid += 1

        # print(code_tree.pretty())
        stats = SExprStats()
        stats.visit(code_tree)
        counts = stats.counts
        global_counter += counts
        entry = {
            "code": code,
            "parse_status": parse_status,
            "counts": counts
        }
        task_stats["per_solution_counts"].append(entry)
    task_stats["total_counts"] = global_counter
    # print(json.dumps(global_stats, indent=4))
    print(f"{emp_valid}/{len(all)} check valid")
    print(f"{repaired}/{len(all)} repaired")
    print(f"{skipped}/{len(all)} skipped")

    all_tasks_count[task_id] = task_stats

# save it to gens directory
# counts_path = gens_path + f"/counts.json"
counts_path = gens_path + f"/counts_temp.json"
with open(counts_path, "w") as f:
    json.dump(all_tasks_count, f, indent=4)
    print(f"Counts saved to {counts_path}")
# Out:
# gpt-4o 205
# 160
# Task 00d62c1b:
# 106/150 valid
# 148/150 check valid
# 2/150 repaired
# 0/150 skipped
# Task 025d127b:
# 139/150 valid
# 149/150 check valid
# 0/150 repaired
# 1/150 skipped
# Task 05f2a901:
# 141/150 valid
# 149/150 check valid
# 0/150 repaired
# 1/150 skipped
# Task 08ed6ac7:
# 111/175 valid
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 98
#      95 skipped = 0
#      96 for code in all:
#      97     # print(code)
# ---> 98     code, parse_status, code_tree = try_parse_sexpr(code)
#      99     if parse_status == "invalid":
#     100         skipped += 1
#
# Cell In[4], line 29, in try_parse_sexpr(code)
#      27 def try_parse_sexpr(code):
#      28     try:
# ---> 29         code_tree = sexpr_parser.parse(code)
#      30         return code , "valid", code_tree
#      31     except Exception as e:
#      32         # print(e)
#
# File ~/repos/arc_stuff/arga-arc/.venv/lib/python3.11/site-packages/lark/lark.py:658, in Lark.parse(self, text, start, on_error)
#     640 def parse(self, text: str, start: Optional[str]=None, on_error: 'Optional[Callable[[UnexpectedInput], bool]]'=None) -> 'ParseTree':
#     641     """Parse the given text, according to the options provided.
#     642
#     643     Parameters:
#    (...)
#     656
#     657     """
# --> 658     return self.parser.parse(text, start=start, on_error=on_error)
#
# File ~/repos/arc_stuff/arga-arc/.venv/lib/python3.11/site-packages/lark/parser_frontends.py:104, in ParsingFrontend.parse(self, text, start, on_error)
#     102 kw = {} if on_error is None else {'on_error': on_error}
#     103 stream = self._make_lexer_thread(text)
# --> 104 return self.parser.parse(stream, chosen_start, **kw)
#
# File ~/repos/arc_stuff/arga-arc/.venv/lib/python3.11/site-packages/lark/parsers/earley.py:279, in Parser.parse(self, lexer, start)
#     276     else:
#     277         columns[0].add(item)
# --> 279 to_scan = self._parse(lexer, columns, to_scan, start_symbol)
#     281 # If the parse was successful, the start
#     282 # symbol should have been completed in the last step of the Earley cycle, and will be in
#     283 # this column. Find the item for the start_symbol, which is the root of the SPPF tree.
#     284 solutions = [n.node for n in columns[-1] if n.is_complete and n.node is not None and n.s == start_symbol and n.start == 0]
#
# File ~/repos/arc_stuff/arga-arc/.venv/lib/python3.11/site-packages/lark/parsers/xearley.py:150, in Parser._parse(self, stream, columns, to_scan, start_symbol)
#     148 i = 0
#     149 for token in stream:
# --> 150     self.predict_and_complete(i, to_scan, columns, transitives)
#     152     to_scan = scan(i, to_scan)
#     154     if token == '\n':
#
# File ~/repos/arc_stuff/arga-arc/.venv/lib/python3.11/site-packages/lark/parsers/earley.py:135, in Parser.predict_and_complete(self, i, to_scan, columns, transitives)
#     132 if is_empty_item:
#     133     held_completions[item.rule.origin] = item.node
# --> 135 originators = [originator for originator in columns[item.start] if originator.expect is not None and originator.expect == item.s]
#     136 for originator in originators:
#     137     new_item = originator.advance()
#
# File ~/repos/arc_stuff/arga-arc/.venv/lib/python3.11/site-packages/lark/parsers/earley.py:135, in <listcomp>(.0)
#     132 if is_empty_item:
#     133     held_completions[item.rule.origin] = item.node
# --> 135 originators = [originator for originator in columns[item.start] if originator.expect is not None and originator.expect == item.s]
#     136 for originator in originators:
#     137     new_item = originator.advance()
#
# File ~/repos/arc_stuff/arga-arc/.venv/lib/python3.11/site-packages/lark/grammar.py:20, in Symbol.__eq__(self, other)
#      18 def __eq__(self, other):
#      19     assert isinstance(other, Symbol), other
# ---> 20     return self.is_term == other.is_term and self.name == other.name
#
# File ~/repos/arc_stuff/arga-arc/.venv/lib/python3.11/site-packages/lark/lexer.py:269, in Token.__eq__(self, other)
#     266 if isinstance(other, Token) and self.type != other.type:
#     267     return False
# --> 269 return str.__eq__(self, other)
#
# KeyboardInterrupt:

# %% [markdown]
# # Get counts only for invalid

# %%
# gens_path = "dsl/v0_3/generations/gens_test"
gens_path = "dsl/v0_3/generations/arga_gpt4o_m100_20240516"

# read the log file
with open(gens_path + "/log.txt") as f:
    log = f.read()

# parse the log file
model, num_gens, log = parse_log(gens_path + "/log.txt")
print(model, num_gens)

invalid_stats = {
    "per_task": {},
}

# log = log[:1]
print(f"{len(log)} tasks") 
all_total, all_valid, all_invalid, all_repaired = 0, 0, 0, 0
for task_id, n_valid, n_invalid in log:
    n_total = n_valid + n_invalid

    valid_file = gens_path + f"/{task_id}_valid.txt"
    invalid_file = gens_path + f"/{task_id}_invalid.txt"

    with open(valid_file, "r") as f:
        valid = json.load(f)
    with open(invalid_file, "r") as f:
        invalid = json.load(f)
    assert len(valid) == n_valid
    assert len(invalid) == n_invalid

    all_total += n_total
    all_valid += n_valid
    all_invalid += n_invalid

    invalid_ratio = n_invalid / n_total 


    # shuffle invlaid entries
    np.random.shuffle(invalid)

    cummulative_counts = []
    current_counts = Counter()
    for entry in invalid:
        response = json.loads(entry["response"])
        code = response["code"]
        code, parse_status, code_tree = try_parse_sexpr(code)
        if parse_status == "invalid":
            continue
        stats = SExprStats()
        stats.visit(code_tree)
        current_counts += counts
        cummulative_counts.append(current_counts.copy())
        # cummulative_counts.append(current_counts)

    n_repaired = len(cummulative_counts)
    all_repaired += n_repaired

    invalid_stats["per_task"][task_id] = {
        "n_total": n_total,
        "n_invalid": n_invalid,
        "invalid_ratio": invalid_ratio,
        "n_repaired": n_repaired,
        "cummulative_counts": cummulative_counts,
    }

    print(f"Task {task_id}:")
    print(f"  {n_invalid}/{n_total} invalid")
    print(f"  {invalid_ratio:.2f} invalid ratio")
    print(f"  {n_repaired}/{n_invalid} repaired")

invalid_stats["all"] = {
    "n_total": all_total,
    "n_invalid": all_invalid,
    "invalid_ratio": all_invalid / all_total,
    "n_repaired": all_repaired,
}
# print(json.dumps(invalid_stats, indent=4))

# save it to gens directory
invalid_stats_path = gens_path + f"/invalid_counts.json"
with open(invalid_stats_path, "w") as f:
    json.dump(invalid_stats, f, indent=4)
    print(f"Counts saved to {invalid_stats_path}")
# Out:
# gpt-4o 205
# 160 tasks
# Task 00d62c1b:
#   44/150 invalid
#   0.29 invalid ratio
#   44/44 repaired
# Task 025d127b:
#   11/150 invalid
#   0.07 invalid ratio
#   10/11 repaired
# Task 05f2a901:
#   9/150 invalid
#   0.06 invalid ratio
#   8/9 repaired
# Task 08ed6ac7:
#   64/175 invalid
#   0.37 invalid ratio
#   60/64 repaired
# Task 0962bcdd:
#   37/150 invalid
#   0.25 invalid ratio
#   37/37 repaired
# Task 0ca9ddb6:
#   74/175 invalid
#   0.42 invalid ratio
#   72/74 repaired
# Task 0d3d703e:
#   10/150 invalid
#   0.07 invalid ratio
#   8/10 repaired
# Task 0e206a2e:
#   35/150 invalid
#   0.23 invalid ratio
#   35/35 repaired
# Task 150deff5:
#   47/150 invalid
#   0.31 invalid ratio
#   43/47 repaired
# Task 1a07d186:
#   35/150 invalid
#   0.23 invalid ratio
#   32/35 repaired
# Task 1b60fb0c:
#   37/150 invalid
#   0.25 invalid ratio
#   35/37 repaired
# Task 1caeab9d:
#   37/150 invalid
#   0.25 invalid ratio
#   35/37 repaired
# Task 1e0a9b12:
#   9/150 invalid
#   0.06 invalid ratio
#   9/9 repaired
# Task 1f0c79e5:
#   16/150 invalid
#   0.11 invalid ratio
#   16/16 repaired
# Task 2204b7a8:
#   44/150 invalid
#   0.29 invalid ratio
#   43/44 repaired
# Task 22168020:
#   8/150 invalid
#   0.05 invalid ratio
#   8/8 repaired
# Task 22233c11:
#   45/150 invalid
#   0.30 invalid ratio
#   45/45 repaired
# Task 228f6490:
#   39/150 invalid
#   0.26 invalid ratio
#   37/39 repaired
# Task 22eb0ac0:
#   35/150 invalid
#   0.23 invalid ratio
#   34/35 repaired
# Task 25d487eb:
#   22/150 invalid
#   0.15 invalid ratio
#   22/22 repaired
# Task 25d8a9c8:
#   68/175 invalid
#   0.39 invalid ratio
#   64/68 repaired
# Task 25ff71a9:
#   4/150 invalid
#   0.03 invalid ratio
#   4/4 repaired
# Task 272f95fa:
#   89/190 invalid
#   0.47 invalid ratio
#   73/89 repaired
# Task 29c11459:
#   30/150 invalid
#   0.20 invalid ratio
#   29/30 repaired
# Task 2c608aff:
#   33/150 invalid
#   0.22 invalid ratio
#   33/33 repaired
# Task 31aa019c:
#   22/150 invalid
#   0.15 invalid ratio
#   21/22 repaired
# Task 321b1fc6:
#   17/150 invalid
#   0.11 invalid ratio
#   15/17 repaired
# Task 32597951:
#   61/175 invalid
#   0.35 invalid ratio
#   61/61 repaired
# Task 3618c87e:
#   63/175 invalid
#   0.36 invalid ratio
#   63/63 repaired
# Task 363442ee:
#   61/175 invalid
#   0.35 invalid ratio
#   61/61 repaired
# Task 36d67576:
#   39/150 invalid
#   0.26 invalid ratio
#   39/39 repaired
# Task 36fdfd69:
#   22/150 invalid
#   0.15 invalid ratio
#   22/22 repaired
# Task 3906de3d:
#   34/150 invalid
#   0.23 invalid ratio
#   34/34 repaired
# Task 39e1d7f9:
#   37/150 invalid
#   0.25 invalid ratio
#   35/37 repaired
# Task 3aa6fb7a:
#   37/150 invalid
#   0.25 invalid ratio
#   35/37 repaired
# Task 3bdb4ada:
#   45/150 invalid
#   0.30 invalid ratio
#   45/45 repaired
# Task 3c9b0459:
#   17/150 invalid
#   0.11 invalid ratio
#   16/17 repaired
# Task 3e980e27:
#   29/150 invalid
#   0.19 invalid ratio
#   28/29 repaired
# Task 3eda0437:
#   47/150 invalid
#   0.31 invalid ratio
#   45/47 repaired
# Task 4093f84a:
#   29/150 invalid
#   0.19 invalid ratio
#   28/29 repaired
# Task 41e4d17e:
#   24/150 invalid
#   0.16 invalid ratio
#   23/24 repaired
# Task 4258a5f9:
#   8/150 invalid
#   0.05 invalid ratio
#   8/8 repaired
# Task 42a50994:
#   12/150 invalid
#   0.08 invalid ratio
#   12/12 repaired
# Task 4347f46a:
#   56/175 invalid
#   0.32 invalid ratio
#   51/56 repaired
# Task 444801d8:
#   43/150 invalid
#   0.29 invalid ratio
#   42/43 repaired
# Task 447fd412:
#   7/150 invalid
#   0.05 invalid ratio
#   6/7 repaired
# Task 44d8ac46:
#   39/150 invalid
#   0.26 invalid ratio
#   37/39 repaired
# Task 4612dd53:
#   42/150 invalid
#   0.28 invalid ratio
#   38/42 repaired
# Task 50846271:
#   25/150 invalid
#   0.17 invalid ratio
#   25/25 repaired
# Task 50cb2852:
#   43/150 invalid
#   0.29 invalid ratio
#   37/43 repaired
# Task 5168d44c:
#   17/150 invalid
#   0.11 invalid ratio
#   16/17 repaired
# Task 543a7ed5:
#   48/150 invalid
#   0.32 invalid ratio
#   46/48 repaired
# Task 54d9e175:
#   38/150 invalid
#   0.25 invalid ratio
#   34/38 repaired
# Task 5521c0d9:
#   16/150 invalid
#   0.11 invalid ratio
#   16/16 repaired
# Task 5582e5ca:
#   25/150 invalid
#   0.17 invalid ratio
#   22/25 repaired
# Task 57aa92db:
#   31/150 invalid
#   0.21 invalid ratio
#   30/31 repaired
# Task 5c0a986e:
#   15/150 invalid
#   0.10 invalid ratio
#   15/15 repaired
# Task 60b61512:
#   37/150 invalid
#   0.25 invalid ratio
#   37/37 repaired
# Task 6150a2bd:
#   11/150 invalid
#   0.07 invalid ratio
#   11/11 repaired
# Task 63613498:
#   5/150 invalid
#   0.03 invalid ratio
#   5/5 repaired
# Task 6455b5f5:
#   98/205 invalid
#   0.48 invalid ratio
#   90/98 repaired
# Task 67385a82:
#   25/150 invalid
#   0.17 invalid ratio
#   25/25 repaired
# Task 67a3c6ac:
#   19/150 invalid
#   0.13 invalid ratio
#   18/19 repaired
# Task 67a423a3:
#   38/150 invalid
#   0.25 invalid ratio
#   36/38 repaired
# Task 6855a6e4:
#   16/150 invalid
#   0.11 invalid ratio
#   16/16 repaired
# Task 68b16354:
#   16/150 invalid
#   0.11 invalid ratio
#   16/16 repaired
# Task 694f12f3:
#   70/175 invalid
#   0.40 invalid ratio
#   67/70 repaired
# Task 6a1e5592:
#   25/150 invalid
#   0.17 invalid ratio
#   25/25 repaired
# Task 6aa20dc0:
#   21/150 invalid
#   0.14 invalid ratio
#   21/21 repaired
# Task 6c434453:
#   46/150 invalid
#   0.31 invalid ratio
#   45/46 repaired
# Task 6d58a25d:
#   40/150 invalid
#   0.27 invalid ratio
#   40/40 repaired
# Task 6d75e8bb:
#   47/150 invalid
#   0.31 invalid ratio
#   45/47 repaired
# Task 6e82a1ae:
#   42/150 invalid
#   0.28 invalid ratio
#   37/42 repaired
# Task 72322fa7:
#   44/150 invalid
#   0.29 invalid ratio
#   43/44 repaired
# Task 7447852a:
#   41/150 invalid
#   0.27 invalid ratio
#   41/41 repaired
# Task 74dd1130:
#   25/150 invalid
#   0.17 invalid ratio
#   25/25 repaired
# Task 776ffc46:
#   15/150 invalid
#   0.10 invalid ratio
#   15/15 repaired
# Task 794b24be:
#   13/150 invalid
#   0.09 invalid ratio
#   12/13 repaired
# Task 7b6016b9:
#   45/150 invalid
#   0.30 invalid ratio
#   44/45 repaired
# Task 7ddcd7ec:
#   2/150 invalid
#   0.01 invalid ratio
#   2/2 repaired
# Task 7e0986d6:
#   5/150 invalid
#   0.03 invalid ratio
#   5/5 repaired
# Task 7f4411dc:
#   14/150 invalid
#   0.09 invalid ratio
#   12/14 repaired
# Task 810b9b61:
#   2/150 invalid
#   0.01 invalid ratio
#   2/2 repaired
# Task 83302e8f:
#   64/175 invalid
#   0.37 invalid ratio
#   58/64 repaired
# Task 855e0971:
#   20/150 invalid
#   0.13 invalid ratio
#   19/20 repaired
# Task 85c4e7cd:
#   45/150 invalid
#   0.30 invalid ratio
#   41/45 repaired
# Task 868de0fa:
#   84/190 invalid
#   0.44 invalid ratio
#   80/84 repaired
# Task 88a10436:
#   12/150 invalid
#   0.08 invalid ratio
#   11/12 repaired
# Task 890034e9:
#   31/150 invalid
#   0.21 invalid ratio
#   31/31 repaired
# Task 8d510a79:
#   13/150 invalid
#   0.09 invalid ratio
#   12/13 repaired
# Task 913fb3ed:
#   30/150 invalid
#   0.20 invalid ratio
#   30/30 repaired
# Task 91714a58:
#   16/150 invalid
#   0.11 invalid ratio
#   16/16 repaired
# Task 941d9a10:
#   105/205 invalid
#   0.51 invalid ratio
#   96/105 repaired
# Task 952a094c:
#   85/190 invalid
#   0.45 invalid ratio
#   81/85 repaired
# Task 9565186b:
#   17/150 invalid
#   0.11 invalid ratio
#   16/17 repaired
# Task 95990924:
#   83/190 invalid
#   0.44 invalid ratio
#   82/83 repaired
# Task 98cf29f8:
#   28/150 invalid
#   0.19 invalid ratio
#   27/28 repaired
# Task 99fa7670:
#   3/150 invalid
#   0.02 invalid ratio
#   3/3 repaired
# Task 9dfd6313:
#   36/150 invalid
#   0.24 invalid ratio
#   36/36 repaired
# Task 9edfc990:
#   13/150 invalid
#   0.09 invalid ratio
#   13/13 repaired
# Task a1570a43:
#   25/150 invalid
#   0.17 invalid ratio
#   24/25 repaired
# Task a48eeaf7:
#   7/150 invalid
#   0.05 invalid ratio
#   7/7 repaired
# Task a5313dff:
#   27/150 invalid
#   0.18 invalid ratio
#   27/27 repaired
# Task a5f85a15:
#   33/150 invalid
#   0.22 invalid ratio
#   31/33 repaired
# Task a61f2674:
#   83/190 invalid
#   0.44 invalid ratio
#   79/83 repaired
# Task a699fb00:
#   25/150 invalid
#   0.17 invalid ratio
#   23/25 repaired
# Task a79310a0:
#   3/150 invalid
#   0.02 invalid ratio
#   3/3 repaired
# Task a9f96cdd:
#   28/150 invalid
#   0.19 invalid ratio
#   26/28 repaired
# Task aabf363d:
#   4/150 invalid
#   0.03 invalid ratio
#   4/4 repaired
# Task ae3edfdc:
#   20/150 invalid
#   0.13 invalid ratio
#   20/20 repaired
# Task aedd82e4:
#   89/190 invalid
#   0.47 invalid ratio
#   88/89 repaired
# Task b1948b0a:
#   1/150 invalid
#   0.01 invalid ratio
#   1/1 repaired
# Task b230c067:
#   35/150 invalid
#   0.23 invalid ratio
#   34/35 repaired
# Task b27ca6d3:
#   23/150 invalid
#   0.15 invalid ratio
#   23/23 repaired
# Task b2862040:
#   1/150 invalid
#   0.01 invalid ratio
#   1/1 repaired
# Task b527c5c6:
#   42/150 invalid
#   0.28 invalid ratio
#   41/42 repaired
# Task b548a754:
#   20/150 invalid
#   0.13 invalid ratio
#   20/20 repaired
# Task b60334d2:
#   45/150 invalid
#   0.30 invalid ratio
#   42/45 repaired
# Task b6afb2da:
#   59/175 invalid
#   0.34 invalid ratio
#   56/59 repaired
# Task b7249182:
#   16/150 invalid
#   0.11 invalid ratio
#   16/16 repaired
# Task b775ac94:
#   41/150 invalid
#   0.27 invalid ratio
#   38/41 repaired
# Task b8cdaf2b:
#   36/150 invalid
#   0.24 invalid ratio
#   34/36 repaired
# Task ba26e723:
#   70/175 invalid
#   0.40 invalid ratio
#   59/70 repaired
# Task bb43febb:
#   42/150 invalid
#   0.28 invalid ratio
#   40/42 repaired
# Task bda2d7a6:
#   49/150 invalid
#   0.33 invalid ratio
#   49/49 repaired
# Task beb8660c:
#   5/150 invalid
#   0.03 invalid ratio
#   4/5 repaired
# Task c0f76784:
#   83/190 invalid
#   0.44 invalid ratio
#   78/83 repaired
# Task c8f0f002:
#   0/150 invalid
#   0.00 invalid ratio
#   0/0 repaired
# Task c9f8e694:
#   14/150 invalid
#   0.09 invalid ratio
#   12/14 repaired
# Task ce22a75a:
#   11/150 invalid
#   0.07 invalid ratio
#   11/11 repaired
# Task ce9e57f2:
#   47/150 invalid
#   0.31 invalid ratio
#   46/47 repaired
# Task d037b0a7:
#   8/150 invalid
#   0.05 invalid ratio
#   8/8 repaired
# Task d23f8c26:
#   0/150 invalid
#   0.00 invalid ratio
#   0/0 repaired
# Task d2abd087:
#   43/150 invalid
#   0.29 invalid ratio
#   42/43 repaired
# Task d364b489:
#   25/150 invalid
#   0.17 invalid ratio
#   23/25 repaired
# Task d406998b:
#   45/150 invalid
#   0.30 invalid ratio
#   44/45 repaired
# Task d43fd935:
#   10/150 invalid
#   0.07 invalid ratio
#   10/10 repaired
# Task d511f180:
#   38/150 invalid
#   0.25 invalid ratio
#   38/38 repaired
# Task d5d6de2d:
#   18/150 invalid
#   0.12 invalid ratio
#   18/18 repaired
# Task d687bc17:
#   32/150 invalid
#   0.21 invalid ratio
#   30/32 repaired
# Task d89b689b:
#   38/150 invalid
#   0.25 invalid ratio
#   36/38 repaired
# Task d90796e8:
#   31/150 invalid
#   0.21 invalid ratio
#   31/31 repaired
# Task d9f24cd1:
#   18/150 invalid
#   0.12 invalid ratio
#   18/18 repaired
# Task db93a21d:
#   49/150 invalid
#   0.33 invalid ratio
#   43/49 repaired
# Task dc1df850:
#   25/150 invalid
#   0.17 invalid ratio
#   24/25 repaired
# Task dc433765:
#   39/150 invalid
#   0.26 invalid ratio
#   37/39 repaired
# Task ddf7fa4f:
#   25/150 invalid
#   0.17 invalid ratio
#   23/25 repaired
# Task e21d9049:
#   44/150 invalid
#   0.29 invalid ratio
#   42/44 repaired
# Task e26a3af2:
#   16/150 invalid
#   0.11 invalid ratio
#   14/16 repaired
# Task e40b9e2f:
#   46/150 invalid
#   0.31 invalid ratio
#   43/46 repaired
# Task e509e548:
#   32/150 invalid
#   0.21 invalid ratio
#   27/32 repaired
# Task e73095fd:
#   27/150 invalid
#   0.18 invalid ratio
#   26/27 repaired
# Task e76a88a6:
#   21/150 invalid
#   0.14 invalid ratio
#   20/21 repaired
# Task e8593010:
#   65/175 invalid
#   0.37 invalid ratio
#   62/65 repaired
# Task e8dc4411:
#   8/150 invalid
#   0.05 invalid ratio
#   8/8 repaired
# Task ea32f347:
#   82/190 invalid
#   0.43 invalid ratio
#   73/82 repaired
# Task ea786f4a:
#   33/150 invalid
#   0.22 invalid ratio
#   29/33 repaired
# Task ed36ccf7:
#   21/150 invalid
#   0.14 invalid ratio
#   21/21 repaired
# Task f76d97a5:
#   9/150 invalid
#   0.06 invalid ratio
#   8/9 repaired
# Task f8a8fe49:
#   37/150 invalid
#   0.25 invalid ratio
#   37/37 repaired
# Counts saved to dsl/v0_3/generations/arga_gpt4o_m100_20240516/invalid_counts.json
